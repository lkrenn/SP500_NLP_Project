# %% [markdown]
# # Scraping EDGAR for Financial Documents
#
# In this notebook, I will be writing code to retrieve 10K and 10Q reports from a given company, given their tickers. To run this, you will need to install the very powerful sec_edgar_downloader package via

# %%
# !pip install sec_api
# Out:
# Collecting sec_api
#   Downloading https://files.pythonhosted.org/packages/d0/62/69f224113b3762f114e14a461c8e74058f37758399107410ea6b8a0f1810/sec_api-1.0.4-py3-none-any.whl
# Requirement already satisfied: requests in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (from sec_api) (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (from requests->sec_api) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (from requests->sec_api) (2020.12.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (from requests->sec_api) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (from requests->sec_api) (1.24.2)
# Installing collected packages: sec-api
# Successfully installed sec-api-1.0.4

# %% [markdown]
# I was able to pull financial documents from all companies that submitted such documents via the SEC website. However, this was done manually via copy/paste. This is a step that would need to be automated if I were to extrapolate this to other sectors/industries

# %%
import pandas as pd
import os
import h5py
from sec_edgar_downloader import Downloader

# %%
# Open the file
df = pd.read_hdf('1-rets.h5')
df.head()
# Out:
#              A  AABA  AAL  AAMRQ  AAP      AAPL  ABBV  ABC  ABI  ABKFQ  ...  \
# 1996-01-02 NaN   NaN  NaN    NaN  NaN  0.007843   NaN  NaN  NaN    NaN  ...
# 1996-01-03 NaN   NaN  NaN    NaN  NaN  0.000000   NaN  NaN  NaN    NaN  ...
# 1996-01-04 NaN   NaN  NaN    NaN  NaN -0.017508   NaN  NaN  NaN    NaN  ...
# 1996-01-05 NaN   NaN  NaN    NaN  NaN  0.085150   NaN  NaN  NaN    NaN  ...
# 1996-01-08 NaN   NaN  NaN    NaN  NaN  0.010948   NaN  NaN  NaN    NaN  ...
#
#                  XRX  XTO  XYL  YNR  YRCW  YUM  ZBH  ZBRA  ZION  ZTS
# 1996-01-02 -0.003650  NaN  NaN  NaN   NaN  NaN  NaN   NaN   NaN  NaN
# 1996-01-03 -0.000915  NaN  NaN  NaN   NaN  NaN  NaN   NaN   NaN  NaN
# 1996-01-04 -0.021082  NaN  NaN  NaN   NaN  NaN  NaN   NaN   NaN  NaN
# 1996-01-05 -0.011236  NaN  NaN  NaN   NaN  NaN  NaN   NaN   NaN  NaN
# 1996-01-08 -0.001894  NaN  NaN  NaN   NaN  NaN  NaN   NaN   NaN  NaN
#
# [5 rows x 1110 columns]

# %% [markdown]
# ## Pulling Data From One Company

# %% [markdown]
# The company ticker can be used to scrape the data. I will demonstrate a quick example (Apple) prior to downloading the full list of companies:

# %%
# from sec_api import QueryApi

# queryApi = QueryApi(api_key="7891993a3f23d1873bccf4d48fd4e4571c9af3cefe758e650f2efb8e0bc5cdba")

# query = {
#     "query": {
#         "query_string": {
#             "query": "cik:1176334, 1413898, 99780 AND formType:\"10-K\""
#         }
#     },
#     "from": "0",
#     "size": "10",
#     "sort": [{ "filedAt": { "order": "desc" } }]
# }

# filings = queryApi.get_filings(query)

# print(filings)

# %%
# Get all 10-K filings for AAPL from 2000 onwards
dl.get("10-K", "AAPL", after="2000-01-01")
# Out:
# 20

# %%
os.listdir("sec-edgar-filings/AAPL")
# Out:
# ['10-K']

# %% [markdown]
# We can see here that in the file created by the package, company documents are organized by their tickers, even though the CIK was used in the request. This will be handy in the backtesting phase.

# %% [markdown]
# # Pulling Data From All Companies
#
# Now, we will pull the data from all the companies found in the .csv file.

# %%
import requests
import json
response = json.loads(requests.get("https://www.sec.gov/files/company_tickers.json").text)

# %%
mapping = pd.DataFrame(response).T
mapping.head()
# Out:
#    cik_str ticker                title
# 0   320193   AAPL           Apple Inc.
# 1   789019   MSFT       MICROSOFT CORP
# 2  1652044   GOOG        Alphabet Inc.
# 3  1018724   AMZN       AMAZON COM INC
# 4    40545     GE  GENERAL ELECTRIC CO

# %%
matches = [x for x in ticks if x not in mapping['ticker'].values]
matches
# Out:
# ['AABA',
#  'AAMRQ',
#  'ABI',
#  'ABKFQ',
#  'ABS',
#  'ABX',
#  'ACAS',
#  'ACKH',
#  'ACS',
#  'AFS.A',
#  'AGN',
#  'AHM',
#  'AKS',
#  'ALXN',
#  'AMCC',
#  'ANDV',
#  'ANDW',
#  'ANRZQ',
#  'ANV',
#  'APC',
#  'APOL',
#  'ARG',
#  'AS',
#  'ASN',
#  'AT',
#  'AV',
#  'AVP',
#  'AW',
#  'AWE',
#  'AYE',
#  'AZA.A',
#  'BAY',
#  'BBT',
#  'BCR',
#  'BDK',
#  'BEV',
#  'BF.B',
#  'BFO',
#  'BGEN',
#  'BGG',
#  'BHGE',
#  'BHMSQ',
#  'BJS',
#  'BKB',
#  'BLS',
#  'BLY',
#  'BMC',
#  'BMET',
#  'BMGCA',
#  'BMS',
#  'BNI',
#  'BOAT',
#  'BOL',
#  'BRCM',
#  'BRK.B',
#  'BRL',
#  'BSC',
#  'BT',
#  'BTUUQ',
#  'BVSN',
#  'BXLT',
#  'CAM',
#  'CBE',
#  'CBS',
#  'CBSS',
#  'CCE',
#  'CCTYQ',
#  'CEG',
#  'CELG',
#  'CEPH',
#  'CFC',
#  'CFL',
#  'CFN',
#  'CGP',
#  'CHA',
#  'CHIR',
#  'CIN',
#  'CIT.A',
#  'CITGQ',
#  'CMB',
#  'CMCSK',
#  'CMVT',
#  'CMX',
#  'CNG',
#  'CNW',
#  'CNXT',
#  'COC.B',
#  'COL',
#  'COV',
#  'CPGX',
#  'CPNLQ',
#  'CPQ',
#  'CRR',
#  'CSE',
#  'CSRA',
#  'CTB',
#  'CTL',
#  'CTX',
#  'CVC',
#  'CVG',
#  'CVH',
#  'CYM',
#  'CYR',
#  'DALRQ',
#  'DCNAQ',
#  'DDR',
#  'DEC',
#  'DF',
#  'DGN',
#  'DI',
#  'DIGI',
#  'DISCK',
#  'DJ',
#  'DNR',
#  'DO',
#  'DPHIQ',
#  'DTV',
#  'DWD',
#  'DWDP',
#  'ECH',
#  'ECO',
#  'EDS',
#  'EFU',
#  'EKDKQ',
#  'EMC',
#  'ENRNQ',
#  'EOP',
#  'EP',
#  'ESRX',
#  'ESV',
#  'ETFC',
#  'ETS',
#  'EVHC',
#  'FBF',
#  'FBO',
#  'FDC',
#  'FDO',
#  'FG',
#  'FII',
#  'FJ',
#  'FLIR',
#  'FLMIQ',
#  'FLTWQ',
#  'FOX',
#  'FPC',
#  'FRX',
#  'FSH',
#  'FSL',
#  'FTL.A',
#  'FTR',
#  'FWLT',
#  'GAPTQ',
#  'GAS',
#  'GDT',
#  'GDW',
#  'GENZ',
#  'GFS.A',
#  'GGP',
#  'GIDL',
#  'GLK',
#  'GMCR',
#  'GOOGL',
#  'GPU',
#  'GR',
#  'GRN',
#  'GSX',
#  'GTW',
#  'GWF',
#  'GX',
#  'HAR',
#  'HBOC',
#  'HCBK',
#  'HCP',
#  'HCR',
#  'HDLM',
#  'HET',
#  'HFS',
#  'HM',
#  'HMA',
#  'HNZ',
#  'HOT',
#  'HPC',
#  'HPH',
#  'HRS',
#  'HSH',
#  'HSP',
#  'I',
#  'IKN',
#  'IMNX',
#  'INCLF',
#  'JAVA',
#  'JCP',
#  'JEC',
#  'JH',
#  'JHF',
#  'JNS',
#  'JNY',
#  'JOS',
#  'JOY',
#  'KATE',
#  'KG',
#  'KM',
#  'KMG',
#  'KORS',
#  'KRB',
#  'KRFT',
#  'KRI',
#  'KSE',
#  'KWP',
#  'LB',
#  'LDG',
#  'LDW.B',
#  'LEHMQ',
#  'LLL',
#  'LLTC',
#  'LLX',
#  'LM',
#  'LO',
#  'LVLT',
#  'LXK',
#  'MAY',
#  'MCIC',
#  'MDR',
#  'MEA',
#  'MEDI',
#  'MEE',
#  'MEL',
#  'MER',
#  'MERQ',
#  'MFE',
#  'MHS',
#  'MI',
#  'MII',
#  'MIL',
#  'MIR',
#  'MJN',
#  'MKG',
#  'MNK',
#  'MOB',
#  'MOLX',
#  'MST',
#  'MTLQQ',
#  'MWI',
#  'MWV',
#  'MWW',
#  'MYG',
#  'MYL',
#  'MZIAQ',
#  'NAE',
#  'NAV',
#  'NBL',
#  'NCC',
#  'NCE',
#  'NFB',
#  'NFX',
#  'NGH',
#  'NLC',
#  'NLV',
#  'NMK',
#  'NOVL',
#  'NRTLQ',
#  'NSI',
#  'NSM',
#  'NVLS',
#  'NWS',
#  'NXTL',
#  'NYN',
#  'NYX',
#  'OAT',
#  'OK',
#  'OMX',
#  'ORX',
#  'OWENQ',
#  'PALM',
#  'PAS',
#  'PBG',
#  'PBY',
#  'PCL',
#  'PCP',
#  'PCS',
#  'PDG',
#  'PEL',
#  'PET',
#  'PETM',
#  'PGL',
#  'PGN',
#  'PHA',
#  'PHB',
#  'PMCS',
#  'PMI',
#  'PNU',
#  'POM',
#  'PPW',
#  'PRD',
#  'PSFT',
#  'PTV',
#  'PVN',
#  'PVT',
#  'PWER',
#  'PWJ',
#  'PX',
#  'PZE',
#  'Q',
#  'QEP',
#  'QLGC',
#  'QTRN',
#  'RAI',
#  'RAL',
#  'RATL',
#  'RBD',
#  'RBK',
#  'RDC',
#  'RDS.A',
#  'RML',
#  'RNB',
#  'ROH',
#  'RSHCQ',
#  'RTN',
#  'RX',
#  'RYC',
#  'SAF',
#  'SAI',
#  'SAPE',
#  'SBL',
#  'SCG',
#  'SDS',
#  'SEBL',
#  'SEG',
#  'SFA',
#  'SFS',
#  'SGID',
#  'SGP',
#  'SHLD',
#  'SHN',
#  'SIAL',
#  'SK',
#  'SLR',
#  'SMI',
#  'SMS',
#  'SNDK',
#  'SNI',
#  'SNT',
#  'SOTR',
#  'SOV',
#  'SPLS',
#  'SRR',
#  'STI',
#  'STJ',
#  'STO',
#  'STR',
#  'SUB',
#  'SUNEQ',
#  'SVU',
#  'SWY',
#  'SXCL',
#  'SYMC',
#  'TCOMA',
#  'TDM',
#  'TE',
#  'TEG',
#  'TEK',
#  'THY',
#  'TIE',
#  'TIN',
#  'TLAB',
#  'TMC',
#  'TMC.A',
#  'TMK',
#  'TNB',
#  'TOS',
#  'TOY',
#  'TRB',
#  'TRW',
#  'TSG',
#  'TSS',
#  'TWC',
#  'TWX',
#  'TXU',
#  'UAA',
#  'UAWGQ',
#  'UCC',
#  'UCM',
#  'UMG',
#  'UN',
#  'UPR',
#  'USBC',
#  'USH',
#  'USHC',
#  'USS',
#  'UST',
#  'USW',
#  'UTX',
#  'UVN',
#  'VAR',
#  'VAT',
#  'VIAB',
#  'VO',
#  'VSTNQ',
#  'VTSS',
#  'WAI',
#  'WAMUQ',
#  'WCG',
#  'WCOEQ',
#  'WFM',
#  'WFT',
#  'WIN',
#  'WLA',
#  'WLP',
#  'WMX',
#  'WNDXQ',
#  'WPX',
#  'WWY',
#  'WYE',
#  'WYND',
#  'XTO',
#  'YNR',
#  'YRCW']

# %%
df = pd.read_csv("2-cusip_ticker.csv", sep='|')
df.head()
# Out:
#                            Issuer Ticker      CUSIP        CIK
# 0                       ALCOA INC     AA  013817101     4281.0
# 1  ALTANA AKTIENGESELLSCHAFT SPON    AAA  02143N103        NaN
# 2  AAA PUB ADJUSTING GRP INC NEW    AAAA  00249C203        NaN
# 3  ASIA AUTOMOTIVE ACQUISITION CO   AAAC  04519K101  1332552.0
# 4  ASIA AUTOMOTIVE ACQUISITION CO  AAACU  04519K200  1332552.0

# %%
matches = df[df['Ticker'].isin(ticks)]
matches.head()
# Out:
#                              Issuer Ticker      CUSIP        CIK
# 55   AMERICAN AIRLINES GROUP INC CO    AAL  02376R102     6201.0
# 67                         AMR CORP  AAMRQ  001765106        NaN
# 80           ADVANCE AUTO PARTS INC    AAP  00751Y106  1158449.0
# 84                APPLE INC;COM NPV   AAPL  037833100   320193.0
# 132         ABBVIE INC COM STK (DE)   ABBV  00287Y109  1551152.0

# %%
sum(matches['CIK'].isna())
# Out:
# 85

# %%
len(ticks)
# Out:
# 1110

# %%
ticks = df.columns

# %%
ticks
# Out:
# Index(['A', 'AABA', 'AAL', 'AAMRQ', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABI',
#        'ABKFQ',
#        ...
#        'XRX', 'XTO', 'XYL', 'YNR', 'YRCW', 'YUM', 'ZBH', 'ZBRA', 'ZION',
#        'ZTS'],
#       dtype='object', length=1110)

# %%
dl.get("10-K", "A", after="2000-01-01")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-198351f2ef74> in <module>
# ----> 1 dl.get("10-K", "A", after="2000-01-01")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sec_edgar_downloader/Downloader.py in get(self, filing, ticker_or_cik, amount, after, before, include_amends, download_details, query)
#     186             filing,
#     187             filings_to_fetch,
# --> 188             download_details,
#     189         )
#     190
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sec_edgar_downloader/_utils.py in download_filings(download_folder, ticker_or_cik, filing_type, filings_to_fetch, include_filing_details)
#     309                         filing.filing_details_url,
#     310                         filing.filing_details_filename,
# --> 311                         resolve_urls=True,
#     312                     )
#     313                 except requests.exceptions.HTTPError as e:  # pragma: no cover
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sec_edgar_downloader/_utils.py in download_and_save_filing(client, download_folder, ticker_or_cik, accession_number, filing_type, download_url, save_filename, resolve_urls)
#     246 ) -> None:
#     247     resp = client.get(
# --> 248         download_url, headers={"User-Agent": generate_random_user_agent()}
#     249     )
#     250     resp.raise_for_status()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     492         else:
#     493             while not is_fp_closed(self._fp):
# --> 494                 data = self.read(amt=amt, decode_content=decode_content)
#     495
#     496                 if data:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     499         # connection, and the user is reading more bytes than will be provided
#     500         # (for example, reading in 1k chunks)
# --> 501         n = self.fp.readinto(b)
#     502         if not n and b:
#     503             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
os.listdir("sec-edgar-filings/")[:5]

# %% [markdown]
# As we can see, the results actually contain the CIKs, so we will need to rename them to get a better idea of tickers. Luckily, there is a complete mapping that is easily downloaded from the following link:
#
# http://rankandfiled.com/#/data/tickers
