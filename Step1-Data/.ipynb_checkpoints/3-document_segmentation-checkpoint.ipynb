# %% [markdown]
# # Layout Parser Tutorial
#
# In this notebook, we will be implementing a Python package called LayoutParser. We will be taking an image-recognition approach to see if perhaps we can do document segmentation that way.

# %%
#!pip install layoutparser

# %%
#!pip install 'git+https://github.com/facebookresearch/detectron2.git@v0.4#egg=detectron2'

# %%
#!pip install fpdf

# %%
#!pip install layoutparser[ocr]

# %%
#!pip install pdfkit

# %%
#!pip install pdfkit
# also requires an installation of wkhtmltopdf

# %%
#!pip install pdf2image

# %%
#!pip install --upgrade html2image

# %%
#!pip install pytesseract

# %%
#!pip install imgkit

# %%
# Need this for Tesseract to function properly
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# Delete unused packages once idea is fully realized
import numpy as np
import pdfkit
import fpdf
import pandas as pd
import os
import pickle
import time
import json
import requests
import re
import pyPDF
import urllib
from bs4 import BeautifulSoup

from pdf2image import convert_from_path, convert_from_bytes
from pytesseract import pytesseract
import layoutparser as lp
import matplotlib.pyplot as plt
import cv2 

#import pytesseract
from PIL import ImageEnhance, ImageFilter, Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-313-39137de5cc5a> in <module>
#      10 import requests
#      11 import re
# ---> 12 import pyPDF
#      13 import urllib
#      14 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'pyPDF'

# %% [markdown]
# First, let's see if we can convert our documents to a picture right away. This may make the process significantly easier.

# %%
with open('../Step1-Data/2-link_dict.pickle', 'rb') as f:
    link_dict = pickle.load(f)

# %%
sample = link_dict['0000006201']
sample_link = sample['Link'].values[0]

# %%
# Used for the requests
heads = {#'Host': 'www.sec.gov', 
         #'Connection': 'close',
         #'Accept': 'application/json',#, text/javascript, */*; q=0.01', 
         'X-Requested-With': 'XMLHttpRequest',
         'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
         }

# %%
response = requests.get(sample_link, headers=heads).text

# %%
from html2image import Html2Image
hti = Html2Image()

# %%
hti.screenshot(url=sample_link, save_as='python_org.png')
# Out:
# ['/Users/lucaskrenn/Documents/HKML/SP500_NLP/SP500_NLP_Project/Step1-Data/python_org.png']

# %% [markdown]
# Unfortunately, after trying many methodologies, it appears that converting the full document's HTML is difficult. Most cases will take a screenshot of whatever is seen in a browser (i.e. the top half of the first page) and nothing else. Therefore, I moved on to first downloading as .pdf, and then working on the pages individually from there. Naturally, this is extremely time consuming, so any faster methodology is greatly appreciated.

# %%
pdfkit.from_url(sample_link, 'out.pdf')
# Out:
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# True

# %%
#hti.screenshot(html_str=response, save_as='red_page.png')

# %%
# need poppler
images = convert_from_bytes(open('Out.pdf', 'rb').read())

# %%
model = lp.Detectron2LayoutModel(
            #config_path = 'lp://PrimaLayout/mask_rcnn_R_50_FPN_3x/config',
            config_path ='lp://PubLayNet/mask_rcnn_X_101_32x8d_FPN_3x/config', # In model catalog
            label_map   = {0: "Text", 1: "Title", 2: "List", 3:"Table", 4:"Figure"}, # In model`label_map`
            #extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8] # Optional
        )

# %%
# Create imglist with all the page indices to speed this up a little
imglist = [images[x] for x in [6,27,52,53,55,56,59,64,86,88,146,200,204,205,226,227]]

# %%
#loop through each page
for image in imglist:
    ocr_agent = lp.ocr.TesseractAgent()
    
    image = np.array(image)
    
    layout = model.detect(image)
    text_blocks = lp.Layout([b for b in layout if b.type == 'Title']) 
    
    for block in text_blocks:
        segment_image = (block.pad(left=5, right=5, top=5, bottom=5).crop_image(image))
        text = ocr_agent.detect(segment_image)
        if text[:4] == 'ITEM':
            print(text)
        #block.set(text=text, inplace=True)
# Out:
# ITEM 1. BUSINESS
#
# ITEM 1A. RISK FACTORS
#
# ITEM 1B. UNRESOLVED STAFF COMMENTS
#
# ITEM 2. PROPERTIES
#
# ITEM 3. LEGAL PROCEEDINGS
#
# ITEM 4. MINE SAFETY DISCLOSURES
#
# ITEM 5. MARKET FOR AMERICAN AIRLINES GROUP’S COMMON STOCK, RELATED STOCKHOLDER MATTERS AND ISSUER PURCHASES
# OF EQUITY SECURITIES
#
# ITEM 5. MARKET FOR AMERICAN AIRLINES GROUP’S COMMON STOCK, RELATED STOCKHOLDER MATTERS AND ISSUER PURCHASES
#
# ITEM 6. SELECTED CONSOLIDATED FINANCIAL DATA
#
# ITEM 7A. QUANTITATIVE AND QUALITATIVE DISCLOSURES ABOUT MARKET RISK
#
# ITEM 8A. CONSOLIDATED FINANCIAL STATEMENTS AND SUPPLEMENTARY DATA OF AMERICAN AIRLINES GROUP INC.
#
# ITEM 8B. CONSOLIDATED FINANCIAL STATEMENTS AND SUPPLEMENTARY DATA OF AMERICAN AIRLINES, INC.
#
# ITEM 9A. CONTROLS AND PROCEDURES
#
# ITEM 9. CHANGES IN AND DISAGREEMENTS WITH ACCOUNTANTS ON ACCOUNTING AND FINANCIAL DISCLOSURE
#
# ITEM 11. EXECUTIVE COMPENSATION
#
# ITEM 14. PRINCIPAL ACCOUNTANT FEES AND SERVICES
#
# ITEM 10. DIRECTORS, EXECUTIVE OFFICERS AND CORPORATE GOVERNANCE
#
# ITEM 9B. OTHER INFORMATION
#
# ITEM 13. CERTAIN RELATIONSHIPS AND RELATED TRANSACTIONS, AND DIRECTOR INDEPENDENCE
#
# ITEM 12. SECURITY OWNERSHIP OF CERTAIN BENEFICIAL OWNERS AND MANAGEMENT AND RELATED STOCKHOLDER MATTERS
#
# ITEM 15. EXHIBITS AND FINANCIAL STATEMENT SCHEDULES
#
# ITEM 16. FORM 10-K SUMMARY

# %% [markdown]
# Great! The new challenge now is that it is extremely time consuming to go through every page. So we will need to perform a regexp and extract only pages that mention \'Item 7\' for example

# %%
response = requests.get(sample_link, headers=heads).text

# %%
soup = BeautifulSoup(response, 'html.parser')

# %%
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
soup.find_all(class_=re.compile("<p style=\"page-break-before: always\" />"))
# Out:
# []

# %%
print(soup.find_all('p'))
# Out:
# []

# %%
classes = [value 
           for element in soup.find_all(class_=True) 
           for value in element["class"]]

# %%
classes
# Out:
# []

# %%
urllib.request.urlopen(sample_link).read()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-302-7d7576045d72> in <module>
# ----> 1 urllib.request.urlopen(sample_link).read()
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
import PyPDF2

def fnPDF_FindText(xFile, xString):
    # xfile : the PDF file in which to look
    # xString : the string to look for
    PageFound = -1
    pdfDoc = pyPdf.PdfFileReader(file(xFile, "rb"))
    for i in range(0, pdfDoc.getNumPages()):
        content = ""
        content += pdfDoc.getPage(i).extractText() + "\n"
        content1 = content.encode('ascii', 'ignore').lower()
        ResSearch = re.search(xString, content1)
        if ResSearch is not None:
            PageFound = i
            break
    return PageFound

# %%
from pyPdf import PdfFileReader, PdfFileWriter

def fnPDF_ExtractPages(xFileNameOriginal, xFileNameOutput, xPageStart, xPageEnd):
    output = PdfFileWriter()
    pdfOne = PdfFileReader(file(xFileNameOriginal, "rb"))
    for i in range(xPageStart, xPageEnd):
        output.addPage(pdfOne.getPage(i))
        outputStream = file(xFileNameOutput, "wb")
        output.write(outputStream)
        outputStream.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-321-efd656d3ff9c> in <module>
# ----> 1 from pyPdf import PdfFileReader, PdfFileWriter
#       2 def fnPDF_ExtractPages(xFileNameOriginal, xFileNameOutput, xPageStart, xPageEnd):
#       3
#       4     output = PdfFileWriter()
#       5     pdfOne = PdfFileReader(file(xFileNameOriginal, "rb"))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyPdf/__init__.py in <module>
# ----> 1 from pdf import PdfFileReader, PdfFileWriter
#       2 __all__ = ["pdf"]
#
# ModuleNotFoundError: No module named 'pdf'

# %%
fnPDF_FindText('Out.pdf', 'Item 7')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-320-e588cc5b0189> in <module>
# ----> 1 fnPDF_FindText('Out.pdf', 'Item 7')
#
# <ipython-input-318-86d6b38e58c4> in fnPDF_FindText(xFile, xString)
#       3     # xString : the string to look for
#       4     PageFound = -1
# ----> 5     pdfDoc = pyPdf.PdfFileReader(file(xFile, "rb"))
#       6     for i in range(0, pdfDoc.getNumPages()):
#       7         content = ""
#
# NameError: name 'pyPdf' is not defined

# %%
# !pip install pyP
# Out:
# Requirement already satisfied: pyPdf in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (1.13)

# %%
import PyPDF2

def fnPDF_FindText(xFile, xString):
    # xfile : the PDF file in which to look
    # xString : the string to look for
    #import pyPdf, re
    PageFound = -1
    pdfDoc = PyPDF2.PdfFileReader(open(xFile, 'rb'))
    for i in range(0, pdfDoc.getNumPages()):
        content = ""
        content += pdfDoc.getPage(i).extractText() + "\n"
        content1 = content.encode('ascii', 'ignore').lower()
        ResSearch = re.search(xString, content1)
        if ResSearch is not None:
            PageFound = i
            break
    return PageFound

# %%
fnPDF_FindText("Out.pdf", r"Item 7")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-358-2f83454277a2> in <module>
# ----> 1 fnPDF_FindText("Out.pdf", r"Item 7")
#
# <ipython-input-356-44f5b2c71a4d> in fnPDF_FindText(xFile, xString)
#      11         content += pdfDoc.getPage(i).extractText() + "\n"
#      12         content1 = content.encode('ascii', 'ignore').lower()
# ---> 13         ResSearch = re.search(xString, content1)
#      14         if ResSearch is not None:
#      15             PageFound = i
#
# ~/opt/anaconda3/lib/python3.7/re.py in search(pattern, string, flags)
#     181     """Scan through string looking for a match to the pattern, returning
#     182     a Match object, or None if no match was found."""
# --> 183     return _compile(pattern, flags).search(string)
#     184
#     185 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: cannot use a string pattern on a bytes-like object

# %%
pdfDoc.getPage(i).extractText()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-359-1a65439bf646> in <module>
# ----> 1 pdfDoc.getPage(i).extractText()
#
# NameError: name 'pdfDoc' is not defined

# %%
Text
# Out:
# ''

# %%
from tika import parser # pip install tika

raw = parser.from_file('Out.pdf')
print(raw['content'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-332-6848afefc581> in <module>
#       1 from tika import parser # pip install tika
#       2
# ----> 3 raw = parser.from_file('Out.pdf')
#       4 print(raw['content'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tika/parser.py in from_file(filename, serverEndpoint, service, xmlContent, headers, config_path, requestOptions)
#      38     '''
#      39     if not xmlContent:
# ---> 40         output = parse1(service, filename, serverEndpoint, headers=headers, config_path=config_path, requestOptions=requestOptions)
#      41     else:
#      42         output = parse1(service, filename, serverEndpoint, services={'meta': '/meta', 'text': '/tika', 'all': '/rmeta/xml'},
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tika/tika.py in parse1(option, urlOrPath, serverEndpoint, verbose, tikaServerJar, responseMimeType, services, rawResponse, headers, config_path, requestOptions)
#     336         status, response = callServer('put', serverEndpoint, service, f,
#     337                                       headers, verbose, tikaServerJar, config_path=config_path,
# --> 338                                       rawResponse=rawResponse, requestOptions=requestOptions)
#     339
#     340     if file_type == 'remote': os.unlink(path)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tika/tika.py in callServer(verb, serverEndpoint, service, data, headers, verbose, tikaServerJar, httpVerbs, classpath, rawResponse, config_path, requestOptions)
#     552     effectiveRequestOptions.update(requestOptions)
#     553
# --> 554     resp = verbFn(serviceUrl, encodedData, **effectiveRequestOptions)
#     555
#     556     if verbose:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in put(url, data, **kwargs)
#     129     """
#     130
# --> 131     return request('put', url, data=data, **kwargs)
#     132
#     133
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import PyPDF2
pdf_file = open('Out.pdf', 'rb')
read_pdf = PyPDF2.PdfFileReader(pdf_file)
number_of_pages = read_pdf.getNumPages()
page = read_pdf.getPage(0)
page_content = page.extractText()
page_content.encode('ascii', 'ignore').lower()
# Out:
# b''

# %%
import os, subprocess
SCRIPT_DIR = "Out.pdf"#os.path.dirname(os.path.abspath(__file__))
args = ["/usr/local/bin/pdftotext",
        '-enc',
        'UTF-8',
        "{}/my-pdf.pdf".format(SCRIPT_DIR),
        '-']
res = subprocess.run(args, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
output = res.stdout.decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-340-a06419460ac8> in <module>
#       6         "{}/my-pdf.pdf".format(SCRIPT_DIR),
#       7         '-']
# ----> 8 res = subprocess.run(args, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#       9 output = res.stdout.decode('utf-8')
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     470         kwargs['stderr'] = PIPE
#     471
# --> 472     with Popen(*popenargs, **kwargs) as process:
#     473         try:
#     474             stdout, stderr = process.communicate(input, timeout=timeout)
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     773                                 c2pread, c2pwrite,
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#     777             # Cleanup if the child failed starting.
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1520                         if errno_num == errno.ENOENT:
#    1521                             err_msg += ': ' + repr(err_filename)
# -> 1522                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1523                 raise child_exception_type(err_msg)
#    1524
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/bin/pdftotext': '/usr/local/bin/pdftotext'

# %%
#!pip install tika
# Out:
# Collecting tika
#   Downloading https://files.pythonhosted.org/packages/96/07/244fbb9c74c0de8a3745cc9f3f496077a29f6418c7cbd90d68fd799574cb/tika-1.24.tar.gz
# Requirement already satisfied: setuptools in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (from tika) (41.4.0)
# Requirement already satisfied: requests in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (from tika) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (from requests->tika) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (from requests->tika) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (from requests->tika) (2021.5.30)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/lucaskrenn/opt/anaconda3/lib/python3.7/site-packages (from requests->tika) (3.0.4)
# Building wheels for collected packages: tika
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-1.24-cp37-none-any.whl size=32884 sha256=f850267388a697f23877de18cd353e78d4a3186af6c419f8c80e0975a36f7961
#   Stored in directory: /Users/lucaskrenn/Library/Caches/pip/wheels/73/9c/f5/0b1b738442fc2a2862bef95b908b374f8e80215550fb2a8975
# Successfully built tika
# Installing collected packages: tika
# Successfully installed tika-1.24

# %%
start = time.time()
text = ocr_agent.detect(images[27])
end = time.time()
print(end-start)
# Out:
# 10.175542831420898

# %%
text
# Out:
# 'Table of Contents\n\nITEM 1A. RISK FACTORS\n\nBelow are certain risk factors that may affect our business, results of operations and financial condition, or the trading price of our common stock or\nother securities. We caution the reader that these risk factors may not be exhaustive. We operate in a continually changing business environment, and\nnew risks and uncertainties emerge from time to time. Management cannot predict such new risks and uncertainties, nor can it assess the extent to which\nany of the risk factors below or any such new risks and uncertainties, or any combination thereof, may impact our business.\n\nRisks Related to our Business\n\nThe outbreak and global spread of COVID-19 has resulted in a severe decline in demand for air travel which has adversely impacted our\nbusiness, operating results, financial condition and liquidity. The duration and severity of the COVID-19 pandemic, and similar public health\nthreats that we may face in the future, could result in additional adverse effects on our business, operating results, financial condition and\nliquidity.\n\nThe COVID-19 outbreak, along with the measures governments and private organizations worldwide have implemented in an attempt to contain the\nspread of this pandemic, has resulted in a severe decline in demand for air travel, which has adversely affected our business, operations and financial\ncondition to an unprecedented extent. Measures ranging from travel restrictions, including testing regimes, “stay at home” and quarantine orders,\nlimitations on public gatherings to cancellation of public events and many others have resulted in a precipitous decline in demand for both domestic and\ninternational business and leisure travel. In response to this material deterioration in demand, we have taken a number of aggressive actions to ameliorate\nour business, operations and financial condition. We have focused on reducing our capacity, making structural changes to our fleet, implementing cost\nreductions, preserving cash and improving our overall liquidity position. We have reduced our system-wide capacity and will continue to monitor conditions\nand to proactively evaluate and adjust our schedule to match demand. Additionally, we have retired certain mainline aircraft earlier than planned, including\nAirbus A330-200, Boeing 757, Boeing 767, Airbus A330-300 and Embraer 190 aircraft as well as regional aircraft, including certain Embraer 140 and\nBombardier CRJ200 aircraft, which we expect will allow us to be more efficient by reducing the number of sub-fleets we operate, and we have also placed\na number of Boeing 737-800 aircraft into temporary storage. We have moved quickly to attempt to better align our costs with our reduced schedule and\nmade other cost-saving initiatives (including reductions in maintenance expense, marketing expense, event and training expense, airport facilities\nexpense, salaries and benefits expense, and other volume-related expense reductions, including fuel). Nonetheless, we incurred significant negative\noperating cash flow in 2020, we continue to do so, and we expect to continue to do so until there is a significant recovery in demand for air travel. The\nduration and severity of the COVID-19 pandemic remain uncertain, and there can be no assurance that any of the mitigating actions we have taken will\nsuffice to sustain our business and operations through this pandemic.\n\nWe have taken and will take additional actions to improve our financial position, including measures to improve liquidity, such as obtaining financial\nassistance under the CARES Act and the PSP Extension Law. In 2020, we received approximately $6.0 billion in financial assistance from Treasury\nthrough PSP1 established under the CARES Act. Pursuant to PSP2 established under the PSP Extension Law, Treasury is to provide us financial\nassistance to be paid in installments expected to total at least $3.0 billion in the aggregate, of which $1.5 billion w ...

# %%
images[27]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1653x2339 at 0x7FC4C2245AD0>

# %%
import pdfminer

text = pdfminer.high_level.extract_text('Out.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-371-c44d405c35a7> in <module>
#       1 import pdfminer
#       2
# ----> 3 text = pdfminer.high_level.extract_text('Out.pdf')
#
# AttributeError: module 'pdfminer' has no attribute 'high_level'

# %%
#!pip install pdfminer
# Out:
# Collecting pdfminer
#   Downloading https://files.pythonhosted.org/packages/71/a3/155c5cde5f9c0b1069043b2946a93f54a41fd72cc19c6c100f6f2f5bdc15/pdfminer-20191125.tar.gz (4.2MB)
#      |████████████████████████████████| 4.2MB 2.1MB/s eta 0:00:01
# Collecting pycryptodome (from pdfminer)
#   Downloading https://files.pythonhosted.org/packages/49/c7/afb27683063b669a15c6599fe5ac8678020acf9e9ab6739cb8ef969255fe/pycryptodome-3.10.1-cp35-abi3-macosx_10_9_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 994kB/s eta 0:00:01
# Building wheels for collected packages: pdfminer
#   Building wheel for pdfminer (setup.py) ... done
#   Created wheel for pdfminer: filename=pdfminer-20191125-cp37-none-any.whl size=6140082 sha256=55780a62f76cf05e870aa1146dc76f13e0f61ee7efb2ee1df3aacbdb9c3440e2
#   Stored in directory: /Users/lucaskrenn/Library/Caches/pip/wheels/e1/00/af/720a55d74ba3615bb4709a3ded6dd71dc5370a586a0ff6f326
# Successfully built pdfminer
# Installing collected packages: pycryptodome, pdfminer
# Successfully installed pdfminer-20191125 pycryptodome-3.10.1

# %%
from tika import parser

rawText = parser.from_file('Out.pdf')

rawList = rawText['content'].splitlines()

# %%
rawList
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'aal-20201231',
#  '',
#  '',
#  'UNITED\tSTATES\tSECURITIES\tAND\tEXCHANGE\tCOMMISSION',
#  'Washington,\tD.C.\t20549',
#  '',
#  'FORM10-K',
#  '',
#  '☒ ANNUAL\tREPORT\tPURSUANT\tTO\tSECTION\t13\tOR\t15(d)\tOF\tTHE\tSECURITIES\tEXCHANGE\tACT\tOF\t1934',
#  'For\tthe\tFiscal\tYear\tEnded\tDecember\t31,\t2020',
#  '',
#  '☐ TRANSITION\tREPORT\tPURSUANT\tTO\tSECTION\t13\tOR\t15(d)\tOF\tTHE\tSECURITIES\tEXCHANGE\tACT\tOF\t1934',
#  'For\tthe\tTransition\tPeriod\tFrom\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tto\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '',
#  'Commission\tfile\tnumber\t1-8400',
#  '',
#  'American\tAirlines\tGroup\tInc.',
#  '(Exact\tname\tof\tregistrant\tas\tspecified\tin\tits\tcharter)',
#  '',
#  'Delaware 75-1825172',
#  '(State\tor\tother\tjurisdiction\tof\tincorporation\tor\torganization) (I.R.S.\tEmployer\tIdentification\tNo.)',
#  '1\tSkyview\tDrive, Fort\tWorth, Texas 76155 (817) 963-1234',
#  '(Address\tof\tprincipal\texecutive\toffices,\tincluding\tzip\tcode) Registrant’s\ttelephone\tnumber,\tincluding\tarea\tcode',
#  '',
#  '(Former\tname,\tformer\taddress\tand\tformer\tfiscal\tyear,\tif\tchanged\tsince\tlast\treport)',
#  '',
#  'Securities\tregistered\tpursuant\tto\tSection\t12(b)\tof\tthe\tAct:',
#  '',
#  'Title\tof\teach\tclass \t Trading\tSymbol(s) \t Name\tof\teach\texchange\ton\twhich\tregistered',
#  'Common\tStock,\t$0.01\tpar\tvalue\tper\tshare \t AAL \t The\tNasdaq\tGlobal\tSelect\tMarket',
#  '',
#  'Securities\tregistered\tpursuant\tto\tSection\t12(g)\tof\tthe\tAct:\tNone',
#  '',
#  'Commission\tfile\tnumber\t1-2691',
#  '',
#  'American\tAirlines,\tInc.',
#  '(Exact\tname\tof\tregistrant\tas\tspecified\tin\tits\tcharter)',
#  '',
#  'Delaware 13-1502798',
#  '(State\tor\tother\tjurisdiction\tof\tincorporation\tor\torganization) (I.R.S.\tEmployer\tIdentification\tNo.)',
#  '',
#  '1\tSkyview\tDrive, Fort\tWorth, Texas 76155 (817)963-1234',
#  '(Address\tof\tprincipal\texecutive\toffices,\tincluding\tzip\tcode) Registrant’s\ttelephone\tnumber,\tincluding\tarea\tcode',
#  '',
#  'Securities\tregistered\tpursuant\tto\tSection\t12(b)\tof\tthe\tAct:\tNone',
#  'Securities\tregistered\tpursuant\tto\tSection\t12(g)\tof\tthe\tAct:\tNone',
#  '',
#  '____________________________________________________',
#  '\t',
#  '',
#  '',
#  '',
#  'Indicate\tby\tcheck\tmark\tif\tthe\tregistrant\tis\ta\twell-known\tseasoned\tissuer,\tas\tdefined\tin\tRule\t405\tof\tthe\tSecurities\tAct.',
#  '',
#  'American\tAirlines\tGroup\tInc. Yes ☒ \t\t No ☐',
#  'American\tAirlines,\tInc. Yes ☒ \t\t No ☐',
#  '',
#  'Indicate\tby\tcheck\tmark\tif\tthe\tregistrant\tis\tnot\trequired\tto\tfile\treports\tpursuant\tto\tSection\t13\tor\tSection\t15(d)\tof\tthe\tAct.',
#  '',
#  'American\tAirlines\tGroup\tInc. Yes ☐ \t\t No ☒',
#  'American\tAirlines,\tInc. Yes ☐ \t\t No ☒',
#  '',
#  'Indicate\tby\tcheck\tmark\twhether\tthe\tregistrant\t(1)\thas\tfiled\tall\treports\trequired\tto\tbe\tfiled\tby\tSection\t13\tor\t15(d)\tof\tthe\tSecurities\tExchange\tAct\tof\t1934',
#  'during\tthe\tpreceding\t12\tmonths\t(or\tfor\tsuch\tshorter\tperiod\tthat\tthe\tregistrant\twas\trequired\tto\tfile\tsuch\treports),\tand\t(2)\thas\tbeen\tsubject\tto\tsuch\tfiling',
#  'requirements\tfor\tthe\tpast\t90\tdays.',
#  '',
#  'American\tAirlines\tGroup\tInc. Yes ☒ \t\t No ☐',
#  'American\tAirlines,\tInc. Yes ☒ \t\t No ☐',
#  '',
#  'Indicate\tby\tcheck\tmark\twhether\tthe\tregistrant\thas\tsubmitted\telectronically\tevery\tInteractive\tData\tFile\trequired\tto\tbe\tsubmitted\tpursuant\tto\tRule\t405\tof',
#  'Regulation\tS-T\t(§232.405\tof\tthis\tchapter)\tduring\tthe\tpreceding\t12\tmonths\t(or\tfor\tsuch\tshorter\tperiod\tthat\tthe\tregistrant\twas\trequired\tto\tsubmit\tsuch\tfiles).',
#  '',
#  'American\tAirlines\tGroup\tInc. Yes ☒ \t\t No ☐',
#  'American\tAirlines,\tInc. Yes ☒ \t\t No ☐',
#  '',
#  'Indicate\tby\tcheck\tmark\twhether\tthe\tregistrant\tis\ta\tlarge\taccelerated\tfiler,\tan\taccelerated\tfiler,\ta\tnon-accelerated\tfiler,\ta\tsmaller\treporting\tcompany,\tor\tan',
#  'emerging\t growth\t company.\t See\t the\t definitions\t of\t “large\t accelerated\t filer,”\t “accelerated\t filer,”\t “smaller\t reporting\t company,”\t and\t “emerging\t growth',
#  'company”\tin\tRule\t12b-2\tof\tthe\tExchange\tAct.',
#  '',
#  'American\tAirlines\tGroup\tInc. ☒ Large\taccelerated\tfiler ☐ Accelerated\tfiler ☐ Non-accelerated\tfiler ☐ Smaller\treporting\tcompany ☐ Emerging\tgrowth\tcompany',
#  'American\tAirlines,\tInc. ☐ Large\taccelerated\tfiler ☐ Accelerated\tfiler ☒ Non-accelerated\tfiler ☐ Smaller\treporting\tcompany ☐ Emerging\tgrowth\tcompany',
#  '',
#  'If\tan\temerging\tgrowth\tcompany,\tindicate\tby\tcheck\tmark\tif\tthe\tregistrant\thas\telected\tnot\tto\tuse\tthe\textended\ttransition\tperiod\tfor\tcomplying\twith\tany\tnew',
#  'or\trevised\tfinancial\taccounting\tstandards\tprovided\tpursuant\tto\tSection\t13(a)\tof\tthe\tExchange\tAct.',
#  '',
#  'American\tAirlines\tGroup\tInc. ☐',
#  'American\tAirlines,\tInc. ☐',
#  '',
#  'Indicate\tby\tcheck\tmark\twhether\tthe\tregistrant\thas\tfiled\ta\treport\ton\tand\tattestation\tto\tits\tmanagement’s\tassessment\tof\tthe\teffectiveness\tof\tits\tinternal',
#  'control\tover\tfinancial\treporting\tunder\tSection\t404(b)\tof\tthe\tSarbanes-Oxley\tAct\t(15\tU.S.C.\t7262(b))\tby\tthe\tregistered\tpublic\taccounting\tfirm\tthat\tprepared',
#  'or\tissued\tits\taudit\treport.',
#  '',
#  'American\tAirlines\tGroup\tInc. Yes ☒ \t\t No ☐',
#  'American\tAirlines,\tInc. Yes ☒ \t\t No ☐',
#  '',
#  'Indicate\tby\tcheck\tmark\twhether\tthe\tregistrant\tis\ta\tshell\tcompany\t(as\tdefined\tin\tRule\t12b-2\tof\tthe\tAct).',
#  '',
#  'American\tAirlines\tGroup\tInc. Yes ☐ \t\t No ☒',
#  'American\tAirlines,\tInc. Yes ☐ \t\t No ☒',
#  '',
#  'As\tof\tFebruary\t12,\t2021,\tthere\twere\t 639,675,800\tshares\tof\tAmerican\tAirlines\tGroup\tInc.\tcommon\tstock\toutstanding.\tThe\taggregate\tmarket\tvalue\tof\tthe',
#  'voting\tstock\theld\tby\tnon-affiliates\tof\tthe\tregistrant\tas\tof\tJune\t30,\t2020,\twas\tapproximately\t$6.6\tbillion.',
#  '',
#  'As\tof\tFebruary\t12,\t2021,\t there\twere\t 1,000\tshares\tof\tAmerican\tAirlines,\t Inc.\tcommon\tstock\toutstanding,\tall\tof\twhich\twere\theld\tby\tAmerican\tAirlines',
#  'Group\tInc.',
#  '',
#  'OMISSION\tOF\tCERTAIN\tINFORMATION',
#  'American\tAirlines\tGroup\t Inc.\t and\tAmerican\tAirlines,\t Inc.\tmeet\t the\t conditions\t set\t forth\t in\tGeneral\t Instruction\t I(1)(a)\t and\t (b)\t of\tForm\t10-K\tand\thave',
#  '',
#  'therefore\tomitted\tthe\tinformation\totherwise\tcalled\tfor\tby\tItems\t10-13\tof\tForm\t10-K\tas\tallowed\tunder\tGeneral\tInstruction\tI(2)(c).',
#  '',
#  'DOCUMENTS\tINCORPORATED\tBY\tREFERENCE',
#  'Portions\tof\tthe\tproxy\tstatement\trelated\tto\tAmerican\tAirlines\tGroup\tInc.’s\t2021\tAnnual\tMeeting\tof\tStockholders,\twhich\tproxy\tstatement\twill\tbe\tfiled\tunder',
#  '',
#  'the\tSecurities\tExchange\tAct\tof\t1934\twithin\t120\tdays\tof\tthe\tend\tof\tAmerican\tAirlines\tGroup\tInc.’s\tfiscal\tyear\tended\tDecember\t31,\t2020,\tare\tincorporated',
#  'by\treference\tinto\tPart\tIII\tof\tthis\tAnnual\tReport\ton\tForm\t10-K.',
#  '',
#  '',
#  '',
#  'American\tAirlines\tGroup\tInc.',
#  'American\tAirlines,\tInc.',
#  '',
#  'Form\t10-K',
#  'Year\tEnded\tDecember\t31,\t2020',
#  '',
#  'Table\tof\tContents\t',
#  '',
#  '\t \t Page',
#  'PART\tI',
#  '',
#  'Item\t1.\t\t\t\t\t\t\t Business 7',
#  'Item\t1A.\t\t\t\t Risk\tFactors 28',
#  'Item\t1B.\t\t\t\t Unresolved\tStaff\tComments 53',
#  'Item\t2.\t\t\t\t\t\t\t Properties 54',
#  'Item\t3.\t\t\t\t\t\t\t Legal\tProceedings 56',
#  'Item\t4.\t\t\t\t\t\t\t Mine\tSafety\tDisclosures 56',
#  '',
#  'PART\tII',
#  'Item\t5.\t\t\t\t\t\t\t Market\tfor\tAmerican\tAirlines\tGroup’s\tCommon\tStock,\tRelated\tStockholder\tMatters\tand\tIssuer\tPurchases\tof\tEquity',
#  '',
#  'Securities 57',
#  'Item\t6.\t\t\t\t\t\t\t Selected\tConsolidated\tFinancial\tData 60',
#  'Item\t7.\t\t\t\t\t\t\t Management’s\tDiscussion\tand\tAnalysis\tof\tFinancial\tCondition\tand\tResults\tof\tOperations 65',
#  'Item\t7A.\t\t\t\t Quantitative\tand\tQualitative\tDisclosures\tAbout\tMarket\tRisk 87',
#  'Item\t8A.\t\t\t\t Consolidated\tFinancial\tStatements\tand\tSupplementary\tData\tof\tAmerican\tAirlines\tGroup\tInc. 89',
#  'Item\t8B.\t\t\t\t Consolidated\tFinancial\tStatements\tand\tSupplementary\tData\tof\tAmerican\tAirlines,\tInc. 147',
#  'Item\t9.\t\t\t\t\t\t\t Changes\tIn\tand\tDisagreements\twith\tAccountants\ton\tAccounting\tand\tFinancial\tDisclosure 201',
#  'Item\t9A.\t\t\t\t Controls\tand\tProcedures 201',
#  'Item\t9B. Other\tInformation 205',
#  '',
#  'PART\tIII',
#  'Item\t10.\t\t\t\t Directors,\tExecutive\tOfficers\tand\tCorporate\tGovernance 205',
#  'Item\t11.\t\t\t\t Executive\tCompensation 205',
#  'Item\t12.\t\t\t\t Security\tOwnership\tof\tCertain\tBeneficial\tOwners\tand\tManagement\tand\tRelated\tStockholder\tMatters 205',
#  'Item\t13.\t\t\t\t Certain\tRelationships\tand\tRelated\tTransactions,\tand\tDirector\tIndependence 205',
#  'Item\t14.\t\t\t\t Principal\tAccountant\tFees\tand\tServices 205',
#  '',
#  'PART\tIV',
#  'Item\t15.\t\t\t\t Exhibits\tand\tFinancial\tStatement\tSchedules 206',
#  'Item\t16.\t\t\t\t Form\t10-K\tSummary 227',
#  'SIGNATURES 228',
#  '',
#  '3',
#  '',
#  '',
#  '',
#  'Table\tof\tContents',
#  '',
#  'General',
#  'This\treport\tis\tfiled\tby\tAmerican\tAirlines\tGroup\tInc.\t(AAG)\tand\tits\twholly-owned\tsubsidiary\tAmerican\tAirlines,\tInc.\t(American).\tReferences\tin\tthis\tAnnual',
#  '',
#  'Report\ton\tForm\t10-K\tto\t“we,”\t“us,”\t“our,”\tthe\t“Company”\tand\tsimilar\tterms\trefer\tto\tAAG\tand\tits\tconsolidated\tsubsidiaries.\t“AMR”\tor\t“AMR\tCorporation”',
#  'refers\tto\tthe\tCompany\tduring\tthe\tperiod\tof\ttime\tprior\tto\tits\temergence\tfrom\tChapter\t11\tand\tits\tacquisition\tof\tUS\tAirways\tGroup,\tInc.\t(US\tAirways\tGroup)',
#  'on\tDecember\t9,\t2013\t(the\tMerger).\tReferences\tto\tUS\tAirways\tGroup\tand\tUS\tAirways,\tInc.,\ta\tsubsidiary\tof\tUS\tAirways\tGroup\t(US\tAirways),\trepresent',
#  'the\tentities\tduring\tthe\tperiod\tof\ttime\tprior\tto\tthe\tdissolution\tof\tthose\tentities\tin\tconnection\twith\tAAG’s\tinternal\tcorporate\trestructuring\ton\tDecember\t30,',
#  '2015.\tReferences\tin\tthis\treport\tto\t“mainline”\trefer\tto\tthe\toperations\tof\tAmerican\tonly\tand\texclude\tregional\toperations.',
#  '',
#  'Glossary\tof\tTerms',
#  'For\t the\t convenience\t of\t the\t reader,\t the\t definitions\t of\t certain\t industry\t and\t other\t terms\t used\t in\t this\t report\t have\t been\t consolidated\t into\t a\t glossary',
#  '',
#  'beginning\ton\tpage\t20.',
#  '',
#  'Note\tConcerning\tForward-Looking\tStatements',
#  'Certain\tof\tthe\tstatements\tcontained\tin\tthis\treport\tshould\tbe\tconsidered\tforward-looking\tstatements\twithin\tthe\tmeaning\tof\tthe\tSecurities\tAct\tof\t1933,\tas',
#  '',
#  'amended\t(the\tSecurities\tAct),\tthe\tSecurities\tExchange\tAct\tof\t1934,\tas\tamended\t(the\tExchange\tAct),\tand\tthe\tPrivate\tSecurities\tLitigation\tReform\tAct\tof',
#  '1995.\tThese\t forward-looking\t statements\tmay\t be\t identified\t by\twords\t such\t as\t “may,”\t “will,”\t “expect,”\t “intend,”\t “anticipate,”\t “believe,”\t “estimate,”\t “plan,”',
#  '“project,”\t“could,”\t“should,”\t“would,”\t“continue,”\t“seek,”\t“target,”\t“guidance,”\t“outlook,”\t“if\tcurrent\ttrends\tcontinue,”\t“optimistic,”\t“forecast”\tand\tother\tsimilar',
#  'words.\tSuch\tstatements\tinclude,\tbut\tare\tnot\tlimited\tto,\tstatements\tabout\tour\tplans,\tobjectives,\texpectations,\tintentions,\testimates\tand\tstrategies\tfor\tthe',
#  'future,\tand\tother\tstatements\tthat\tare\tnot\thistorical\tfacts.\tThese\tforward-looking\tstatements\tare\tbased\ton\tour\tcurrent\tobjectives,\tbeliefs\tand\texpectations,',
#  'and\tthey\tare\tsubject\tto\tsignificant\trisks\tand\tuncertainties\tthat\tmay\tcause\tactual\tresults\tand\tfinancial\tposition\tand\ttiming\tof\tcertain\tevents\tto\tdiffer\tmaterially',
#  'from\tthe\tinformation\tin\tthe\tforward-looking\tstatements.\tThese\trisks\tand\tuncertainties\tinclude,\tbut\tare\tnot\tlimited\tto,\tthose\tdescribed\tbelow\tunder\tPart\tI,',
#  'Item\t 1A.\tRisk\t Factors,\t Part\t II,\t Item\t 7.\tManagement’s\tDiscussion\t and\tAnalysis\t of\t Financial\t Condition\t and\tResults\t of\tOperations\t and\t other\t risks\t and',
#  'uncertainties\tlisted\tfrom\ttime\tto\ttime\tin\tour\tfilings\twith\tthe\tSecurities\tand\tExchange\tCommission\t(the\tSEC).',
#  '',
#  'All\tof\tthe\tforward-looking\tstatements\tare\tqualified\tin\ttheir\tentirety\tby\treference\tto\tthe\tfactors\tdiscussed\tin\tPart\tI,\tItem\t1A.\tRisk\tFactors\tand\telsewhere\tin',
#  'this\treport.\tThere\tmay\tbe\tother\tfactors\tof\twhich\twe\tare\tnot\tcurrently\taware\tthat\tmay\taffect\tmatters\tdiscussed\tin\tthe\tforward-looking\tstatements\tand\tmay',
#  'also\tcause\tactual\tresults\tto\tdiffer\tmaterially\tfrom\tthose\tdiscussed.\tIn\tparticular,\tthe\tconsequences\tof\tthe\tcoronavirus\toutbreak\tto\teconomic\tconditions\tand',
#  'the\t travel\t industry\t in\t general\t and\t our\t financial\t position\t and\t operating\t results\t in\t particular\t have\t been\tmaterial,\t are\t changing\t rapidly,\t and\t cannot\t be',
#  'predicted.\t We\t do\t not\t assume\t any\t obligation\t to\t publicly\t update\t or\t supplement\t any\t forward-looking\t statement\t to\t reflect\t actual\t results,\t changes\t in',
#  'assumptions\tor\tchanges\tin\tother\tfactors\taffecting\tsuch\tstatements\tother\tthan\tas\trequired\tby\tlaw.\tForward-looking\tstatements\tspeak\tonly\tas\tof\tthe\tdate\tof',
#  'this\treport\tor\tas\tof\tthe\tdates\tindicated\tin\tthe\tstatements.',
#  '',
#  '4',
#  '',
#  '',
#  '',
#  'Table\tof\tContents',
#  '',
#  'Summary\tRisk\tFactors',
#  'Our\tbusiness\tis\tsubject\tto\ta\tnumber\tof\trisks\tand\tuncertainties\tthat\tmay\taffect\tour\tbusiness,\tresults\tof\toperations\tand\tfinancial\tcondition,\tor\tthe\ttrading',
#  '',
#  'price\tof\tour\tcommon\tstock\tor\tother\tsecurities.\tWe\tcaution\tthe\treader\tthat\tthese\trisk\tfactors\tmay\tnot\tbe\texhaustive.\tWe\toperate\tin\ta\tcontinually\tchanging',
#  'business\tenvironment,\tand\tnew\trisks\tand\tuncertainties\temerge\tfrom\ttime\tto\ttime.\tManagement\tcannot\tpredict\tsuch\tnew\trisks\tand\tuncertainties,\tnor\tcan\tit',
#  'assess\tthe\textent\tto\twhich\tany\tof\tthe\trisk\tfactors\tbelow\tor\tany\tsuch\tnew\trisks\tand\tuncertainties,\tor\tany\tcombination\tthereof,\tmay\timpact\tour\tbusiness.',
#  'These\trisks\tare\tmore\tfully\tdescribed\tin\tPart\tI,\tItem\t1A.\tRisk\tFactors\tThese\trisks\tinclude,\tamong\tothers,\tthe\tfollowing:',
#  '',
#  'Risks\tRelated\tto\tour\tBusiness',
#  '',
#  '• The\toutbreak\tand\tglobal\tspread\tof\tCOVID-19\thas\tresulted\tin\ta\tsevere\tdecline\tin\tdemand\tfor\tair\ttravel\twhich\thas\tand\twill\tcontinue\tto\tadversely',
#  'impact\tour\tbusiness,\toperating\tresults,\tfinancial\tcondition\tand\tliquidity.',
#  '',
#  '• Downturns\tin\teconomic\tconditions\tand\trelated\tdepressed\tdemand\tfor\tair\ttravel\tcould\tadversely\taffect\tour\tbusiness.',
#  '',
#  '• We\twill\tneed\tto\tobtain\tsufficient\tfinancing\tor\tother\tcapital\tto\toperate\tsuccessfully.',
#  '',
#  '• Our\thigh\tlevel\tof\tdebt\tand\tother\tobligations\tmay\tlimit\tour\tability\tto\tfund\tgeneral\tcorporate\trequirements\tand\tobtain\tadditional\tfinancing,\tmay\tlimit',
#  'our\tflexibility\tin\tresponding\tto\tcompetitive\tdevelopments\tand\tcause\tour\tbusiness\tto\tbe\tvulnerable\tto\tadverse\teconomic\tand\tindustry\tconditions.',
#  '',
#  '• We\thave\tsignificant\tpension\tand\tother\tpostretirement\tbenefit\t funding\tobligations,\twhich\tmay\tadversely\taffect\tour\t liquidity,\tresults\tof\toperations',
#  'and\tfinancial\tcondition.',
#  '',
#  '• The\t loss\tof\tkey\tpersonnel\tupon\twhom\twe\tdepend\tto\toperate\tour\tbusiness\tor\t the\t inability\t to\tattract\tand\tdevelop\tadditional\tqualified\tpersonnel',
#  'could\tadversely\taffect\tour\tbusiness.',
#  '',
#  '• Our\tbusiness\thas\tbeen\tand\twill\tcontinue\tto\tbe\taffected\tby\tmany\tchanging\teconomic\tand\tother\tconditions\tbeyond\tour\tcontrol,\t including\tglobal',
#  'events\tthat\taffect\ttravel\tbehavior,\tand\tour\tresults\tof\toperations\tcould\tbe\tvolatile\tand\tfluctuate\tdue\tto\tseasonality.',
#  '',
#  '• Union\tdisputes,\temployee\tstrikes\tand\tother\tlabor-related\tdisruptions,\tor\tour\tinability\tto\totherwise\tmaintain\tlabor\tcosts\tat\tcompetitive\tlevels\tmay',
#  'adversely\taffect\tour\toperations\tand\tfinancial\tperformance.',
#  '',
#  '• If\twe\tencounter\tproblems\twith\tany\tof\tour\tthird-party\tregional\toperators\tor\tthird-party\tservice\tproviders,\tour\toperations\tcould\tbe\tadversely\taffected',
#  'by\ta\tresulting\tdecline\tin\trevenue\tor\tnegative\tpublic\tperception\tabout\tour\tservices.',
#  '',
#  '• Any\tnegative\tpublicity\tstemming\tfrom\tany\tpublic\tincident\tinvolving\tour\tcompany,\tour\tpeople,\tour\tbrand\tor\tany\tof\tour\tregional,\tcodeshare\tor\tjoint',
#  'business\toperators\tor\tany\tdamage\tto\tour\treputation\tor\tbrand\timage\tcould\tadversely\taffect\tour\tbusiness\tor\tfinancial\tresults.',
#  '',
#  '• Our\tintellectual\tproperty\trights,\tparticularly\tour\tbranding\trights,\tare\tvaluable,\tand\tany\tinability\tto\tprotect\tthem\tmay\tadversely\taffect\tour\tbusiness',
#  'and\tfinancial\tresults.',
#  '',
#  '• Our\tability\tto\tutilize\tour\tNOL\tCarryforwards\tmay\tbe\tlimited.',
#  '',
#  '• We\thave\ta\tsignificant\tamount\tof\tgoodwill,\twhich\tis\tassessed\tfor\timpairment\tat\tleast\tannually.\tIn\taddition,\twe\tmay\tnever\trealize\tthe\tfull\tvalue\tof',
#  'our\tintangible\tassets\tor\tlong-lived\tassets,\tcausing\tus\tto\trecord\tmaterial\timpairment\tcharges.',
#  '',
#  '5',
#  '',
#  '',
#  '',
#  'Table\tof\tContents',
#  '',
#  'Risks\tRelated\tto\tthe\tAirline\tIndustry',
#  '',
#  '• The\tairline\tindustry\tis\tintensely\tcompetitive\tand\tdynamic.',
#  '',
#  '• The\tcommercial\trelationships\tthat\twe\thave\twith\tother\tairlines,\tincluding\tany\trelated\tequity\tinvestment,\tmay\tnot\tproduce\tthe\treturns\tor\tresults\twe',
#  'expect.',
#  '',
#  '• Our\tbusiness\t is\tvery\tdependent\ton\tthe\tprice\tand\tavailability\tof\taircraft\t fuel\tand\tcontinued\tperiods\tof\thigh\tvolatility\t in\t fuel\tcosts,\t increased\tfuel',
#  'prices\tor\tsignificant\tdisruptions\tin\tthe\tsupply\tof\taircraft\tfuel\tcould\thave\ta\tsignificant\tnegative\timpact\ton\tconsumer\tdemand,\tour\toperating\tresults',
#  'and\tliquidity.',
#  '',
#  '• Our\tbusiness\tis\tsubject\tto\textensive\tgovernment\tregulation,\twhich\tmay\tresult\tin\tincreases\tin\tour\tcosts,\tdisruptions\tto\tour\toperations,\tlimits\ton\tour',
#  'operating\tflexibility,\treductions\tin\tthe\tdemand\tfor\tair\ttravel,\tand\tcompetitive\tdisadvantages.',
#  '',
#  '• We\toperate\ta\tglobal\tbusiness\twith\tinternational\toperations\tthat\tare\tsubject\tto\teconomic\tand\tpolitical\tinstability\tand\thave\tbeen,\tand\tin\tthe\tfuture',
#  'may\tcontinue\tto\tbe,\tadversely\taffected\tby\tnumerous\tevents,\tcircumstances\tor\tgovernment\tactions\tbeyond\tour\tcontrol.',
#  '',
#  '• We\tmay\tbe\tadversely\taffected\tby\tconflicts\toverseas\tor\tterrorist\tattacks;\tthe\ttravel\tindustry\tcontinues\tto\tface\tongoing\tsecurity\tconcerns.',
#  '',
#  '• We\tare\tsubject\tto\trisks\tassociated\twith\tclimate\tchange,\tincluding\tincreased\tregulation\tof\tour\tCO \temissions,\tchanging\tconsumer\tpreferences\tand',
#  'the\tpotential\tincreased\timpacts\tof\tsevere\tweather\tevents\ton\tour\toperations\tand\tinfrastructure.',
#  '',
#  '• We\tdepend\ton\ta\tlimited\tnumber\tof\tsuppliers\tfor\taircraft,\taircraft\tengines\tand\tparts.',
#  '',
#  '• Delays\tin\tscheduled\taircraft\tdeliveries\tor\tother\tloss\tof\tanticipated\tfleet\tcapacity,\tand\tfailure\tof\tnew\taircraft\tto\tperform\tas\texpected,\tmay\tadversely',
#  'impact\tour\tbusiness,\tresults\tof\toperations\tand\tfinancial\tcondition.',
#  '',
#  '2',
#  '',
#  '6',
#  '',
#  '',
#  '',
#  'Table\tof\tContents',
#  '',
#  'PART\tI\t',
#  '',
#  'ITEM\t1.\tBUSINESS',
#  'Overview',
#  '',
#  'American\tAirlines\tGroup\tInc.\t(AAG),\ta\tDelaware\tcorporation,\tis\ta\tholding\tcompany\tand\tits\tprincipal,\twholly-owned\tsubsidiaries\tare\tAmerican\tAirlines,',
#  'Inc.\t(American),\tEnvoy\tAviation\tGroup\tInc.\t(Envoy),\tPSA\tAirlines,\tInc.\t(PSA)\tand\tPiedmont\tAirlines,\tInc.\t(Piedmont).\tAAG\twas\tformed\tin\t1982\tunder\tthe',
#  'name\tAMR\tCorporation\t(AMR)\tas\tthe\tparent\tcompany\tof\tAmerican,\twhich\twas\tfounded\tin\t1934.',
#  '',
#  'AAG’s\tand\tAmerican’s\tprincipal\texecutive\toffices\tare\t located\tat\t1\tSkyview\tDrive,\tFort\tWorth,\tTexas\t76155\tand\t their\t telephone\tnumber\t is\t817-963-',
#  '1234.',
#  '',
#  'Airline\tOperations',
#  'Together\twith\tour\twholly-owned\tregional\tairline\tsubsidiaries\tand\tthird-party\tregional\tcarriers\toperating\tas\tAmerican\tEagle,\tour\tprimary\tbusiness\tactivity',
#  '',
#  'is\tthe\toperation\tof\ta\tmajor\tnetwork\tair\tcarrier,\tproviding\tscheduled\tair\ttransportation\tfor\tpassengers\tand\tcargo\tthrough\tour\thubs\tin\tCharlotte,\tChicago,',
#  'Dallas/Fort\tWorth,\t Los\tAngeles,\tMiami,\t New\tYork,\t Philadelphia,\t Phoenix\t and\tWashington,\t D.C.\t and\t partner\t gateways,\t including\t in\t London,\tMadrid,',
#  'Seattle/Tacoma,\tSydney\tand\tTokyo\t(among\tothers).',
#  '',
#  'Approximately\t95\tmillion\tpassengers\tboarded\tour\t flights\t in\t2020,\ta\tdecrease\t from\tapproximately\t215\tmillion\tpassengers\t in\t2019.\tDuring\t2020,\twe',
#  'experienced\tan\tunprecedented\tdecline\tin\tthe\tdemand\tfor\tair\ttravel\tdue\tto\tthe\timpact\tof\tcoronavirus\t(COVID-19).\tCOVID-19\thas\tbeen\tdeclared\ta\tglobal',
#  'health\tpandemic\tby\tthe\tWorld\tHealth\tOrganization\tand\thas\tsurfaced\tin\tnearly\tall\tregions\tof\tthe\tworld,\twhich\thas\tdriven\tthe\timplementation\tof\tsignificant,',
#  'government-imposed\tmeasures\tto\tprevent\tor\treduce\tits\tspread,\tincluding\ttravel\trestrictions,\ttesting\tregimes,\tclosing\tof\tborders,\t“stay\tat\thome”\torders\tand',
#  'business\tclosures.\tWhile\tthe\tlength\tand\tseverity\tof\tthe\treduction\tin\tdemand\tdue\tto\tthe\tCOVID-19\tpandemic\tis\tuncertain,\tour\tbusiness,\toperations\tand',
#  'financial\tcondition\tin\t2020\twas\tseverely\timpacted.',
#  '',
#  'As\t of\tDecember\t 31,\t 2020,\twe\t operated\t 855\tmainline\t aircraft\t supported\t by\t our\t regional\t airline\t subsidiaries\t and\t third-party\t regional\t carriers,\twhich',
#  'operated\tan\tadditional\t544\tregional\taircraft.\tSee\tPart\tI,\tItem\t2.\tProperties\tfor\tfurther\tdiscussion\ton\tour\tmainline\tand\tregional\taircraft\tand\t“Regional”\tbelow',
#  'for\tfurther\tdiscussion\ton\tour\tregional\toperations.',
#  '',
#  'American\tis\ta\tfounding\tmember\tof\tthe\t oneworld \tAlliance,\twhich\tbrings\ttogether\ta\tglobal\tnetwork\tof\t13\tworld-class\tmember\tairlines\tand\ttheir\taffiliates,',
#  'working\ttogether\tto\tprovide\ta\tsuperior\tand\tseamless\ttravel\texperience.\tSee\tbelow\tfor\tfurther\tdiscussion\ton\tthe\toneworld\tAlliance\tand\tother\tagreements',
#  'with\tdomestic\tand\tinternational\tairlines.',
#  '',
#  'See\tPart\t II,\t Item\t7.\tManagement’s\tDiscussion\tand\tAnalysis\tof\tFinancial\tCondition\tand\tResults\tof\tOperations\t– “2020\t Financial\tOverview,”\t “AAG’s',
#  'Results\t of\t Operations”\t and\t“American’s\t Results\t of\t Operations” \t for\t further\t discussion\t of\t AAG’s\t and\t American’s\t operating\t results\t and\t operating',
#  'performance.\tAlso,\t see\t Note\t 14\t to\tAAG’s\t Consolidated\t Financial\t Statements\t in\t Part\t II,\t Item\t 8A\t and\t Note\t 12\t to\tAmerican’s\t Consolidated\t Financial',
#  'Statements\tin\tPart\tII,\tItem\t8B\tfor\tinformation\tregarding\toperating\tsegments\tand\tsee\tNote\t1(l)\tto\teach\tof\tAAG’s\tand\tAmerican’s\tConsolidated\tFinancial',
#  'Statements\tin\tPart\tII,\tItems\t8A\tand\t8B,\trespectively,\tfor\tpassenger\trevenue\tby\tgeographic\tregion.',
#  '',
#  'Regional',
#  'Our\tregional\tcarriers\tprovide\tscheduled\tair\t transportation\tunder\t the\tbrand\tname\t“American\tEagle.”\tThe\tAmerican\tEagle\tcarriers\t include\tour\twholly-',
#  '',
#  'owned\tregional\tcarriers\tEnvoy,\tPSA\tand\tPiedmont,\tas\twell\tas\tthird-party\tregional\tcarriers\tincluding\tRepublic\tAirways\tInc.\t(Republic),\tSkyWest\tAirlines,',
#  'Inc.\t (SkyWest),\t and\t Mesa\tAirlines,\t Inc.\t (Mesa).\t In\t addition,\t Compass\tAirlines,\t LLC\t operated\t regional\t jet\t aircraft\t for\t us\t during\t 2020;\t however,\t this',
#  'arrangement\tended\tin\tApril\t2020.\tOur\tregional\tcarriers\tare\tan\tintegral\tcomponent\tof\tour\toperating\tnetwork.\tWe\trely\theavily\ton\tregional\tcarriers\tto\tdrive',
#  'feeder\ttraffic\tto\tour\thubs\tfrom\tlow-density\tmarkets\tthat\tare\tnot\teconomical\tfor\tus\tto\tserve\twith\tlarger,\tmainline\taircraft.\tIn\taddition,\tregional\tcarriers\toffer',
#  'complementary\tservice\tin\tmany\tof\tour\tmainline\tmarkets.\tAll\tAmerican\tEagle\tcarriers\tuse\tlogos,\tservice\tmarks,\taircraft\tpaint\tschemes\tand\tuniforms\tsimilar',
#  'to\t those\tof\tour\tmainline\toperations.\t In\t2020,\tapproximately\t30\tmillion\tpassengers\tboarded\tour\t regional\t carriers’\t planes,\tapproximately\t48%\tof\twhom',
#  'connected\tto\tor\tfrom\tour\tmainline\tflights,\ta\tdecrease\tfrom\tapproximately\t59\tmillion\tpassengers\tin\t2019,\tdue\tto\tthe\teffects\tof\tthe\tCOVID-19\tpandemic.',
#  '',
#  '®',
#  '',
#  '7',
#  '',
#  '',
#  '',
#  'Table\tof\tContents',
#  '',
#  'Substantially\tall\tof\tour\tregional\tcarrier\tarrangements\tare\tin\tthe\tform\tof\tcapacity\tpurchase\tagreements.\tThe\tcapacity\tpurchase\tagreements\tprovide\tthat',
#  'all\t revenues,\t including\tpassenger,\t in-flight,\tancillary,\tmail\tand\t freight\t revenues,\tgo\t to\tus.\tWe\tcontrol\tmarketing,\tscheduling,\t ticketing,\tpricing\tand\tseat',
#  'inventories.\tIn\treturn,\twe\tagree\tto\tpay\tpredetermined\tfees\tto\tthese\tairlines\tfor\toperating\tan\tagreed-upon\tnumber\tof\taircraft,\twithout\tregard\tto\tthe\tnumber',
#  'of\tpassengers\ton\tboard.\t In\taddition,\t these\tagreements\tprovide\tthat\twe\teither\treimburse\tor\tpay\t100%\tof\tcertain\tvariable\tcosts,\tsuch\tas\tairport\t landing',
#  'fees,\tfuel\tand\tpassenger\tliability\tinsurance.',
#  '',
#  'Cargo',
#  'Our\tcargo\tdivision\tprovides\ta\twide\trange\tof\tfreight\tand\tmail\tservices,\twith\tfacilities\tand\tinterline\tconnections\tavailable\tacross\tthe\tglobe.\tIn\t2020,\twe',
#  '',
#  'expanded\tour\tcargo\tservice\tand\tlaunched\tour\tfirst\tcargo-only\tflights\tsince\t1984\tto\ttransport\tcritical\tgoods,\tincluding\tthe\tCOVID-19\tvaccine,\tbetween\tthe',
#  'U.S.\tand\tEurope,\tAsia\tand\tLatin\tAmerica.\tWe\toperated\tmore\tthan\t5,200\tcargo-only\tflights\tserving\t41\tdestinations.\tThese\tcargo-only\tflights\thave\thelped',
#  'our\tcustomers\tmove\tmore\tthan\t167\tmillion\tpounds\tof\tcritical\tgoods\taround\tthe\tworld\tamidst\tthe\tCOVID-19\tpandemic.',
#  '',
#  'Distribution\tand\tMarketing\tAgreements',
#  'Passengers\tcan\tpurchase\ttickets\tfor\ttravel\ton\tAmerican\tthrough\tseveral\tdistribution\tchannels,\tincluding\tour\twebsite\t( www.aa.com),\tour\tmobile\tapp,\tour',
#  '',
#  'reservations\tcenters\tand\tthird-party\tdistribution\tchannels,\tincluding\tthose\tprovided\tby\tor\tthrough\tglobal\tdistribution\tsystems\t(e.g.,\tAmadeus,\tSabre\tand',
#  'Travelport),\t conventional\t travel\t agents,\t travel\tmanagement\t companies\t and\t online\t travel\t agents\t (e.g.,\t Expedia,\t including\t its\t booking\t sites\tOrbitz\t and',
#  'Travelocity,\tand\tBooking\tHoldings,\tincluding\tits\tbooking\tsites\tKayak\tand\tPriceline).\tTo\tremain\tcompetitive,\twe\twill\tneed\tto\tmanage\tour\tdistribution\tcosts',
#  'and\t rights\t effectively,\t increase\t our\t distribution\t flexibility\t and\t improve\t the\t functionality\t of\t our\t proprietary\t and\t third-party\t distribution\t channels,\t while',
#  'maintaining\tan\tindustry-competitive\tcost\tstructure.\tFor\tmore\tdiscussion,\tsee\tPart\tI,\tItem\t1A.\tRisk\tFactors\t–\t“We\trely\ton\tthird-party\tdistribution\tchannels',
#  'and\tmust\tmanage\teffectively\tthe\tcosts,\trights\tand\tfunctionality\tof\tthese\tchannels.”',
#  '',
#  'In\tgeneral,\tbeyond\tnonstop\tcity\tpairs,\tcarriers\tthat\thave\tthe\tgreatest\tability\tto\tseamlessly\tconnect\tpassengers\tto\tand\tfrom\tmarkets\thave\ta\tcompetitive',
#  'advantage.\tIn\tsome\tcases,\thowever,\tforeign\tgovernments\tlimit\tU.S.\tair\tcarriers’\trights\tto\ttransport\tpassengers\tbeyond\tdesignated\tgateway\tcities\tin\tforeign',
#  'countries.\tIn\torder\tto\timprove\taccess\tto\tdomestic\tand\tforeign\tmarkets,\twe\thave\tarrangements\twith\tother\tairlines\tincluding\tthrough\tthe\toneworld\tAlliance,',
#  'other\tcooperation\tagreements,\tjoint\tbusiness\tagreements,\tand\tmarketing\trelationships,\tas\tfurther\tdiscussed\tbelow.',
#  '',
#  'Member\tof\toneworld\tAlliance',
#  'American\t is\t a\t founding\tmember\t of\t the\t oneworld\tAlliance,\t which\t currently\t includes\t British\tAirways,\t Cathay\t Pacific,\t Finnair,\t Iberia,\t Japan\tAirlines,',
#  '',
#  'Malaysia\tAirlines,\t Qantas\tAirways\t (Qantas),\t Qatar\tAirways,\t Royal\tAir\t Maroc,\t Royal\t Jordanian,\t S7\tAirlines\t and\t SriLankan\tAirlines.\t Fiji\tAirways\t is\t a',
#  'oneworld\tconnect\tpartner\tand\tAlaska\tAirlines\tis\ta\t oneworld\tmember\telect,\texpected\tto\tjoin\tthe\t oneworld\tAlliance\tin\t2021.\tThe\toneworld\tAlliance\tlinks',
#  'the\tnetworks\tof\tmember\tcarriers\tand\ttheir\trespective\taffiliates\tto\tenhance\tcustomer\tservice\tand\tprovide\tsmooth\tconnections\tto\tthe\tdestinations\tserved\tby',
#  'the\talliance,\tincluding\tlinking\tthe\tcarriers’\tloyalty\tprograms\tand\tproviding\taccess\tto\tthe\tcarriers’\tairport\tlounge\tfacilities.',
#  '',
#  'Cooperation\tand\tJoint\tBusiness\tAgreements',
#  'American\thas\testablished\ta\t transatlantic\t joint\tbusiness\twith\tBritish\tAirways,\tAer\tLingus,\t Iberia\tand\tFinnair,\ta\t transpacific\t joint\tbusiness\twith\tJapan',
#  '',
#  'Airlines\t and\t a\t joint\t business\t relating\t to\tAustralia\t and\tNew\t Zealand\twith\tQantas,\t each\t of\t which\t has\t been\t granted\t antitrust\t immunity.\t Joint\t business',
#  'agreements\tenable\t the\tcarriers\t involved\t to\tcooperate\ton\t flights\tbetween\tparticular\tdestinations\tand\tallow\tpooling\tand\tsharing\tof\tcertain\trevenues\tand',
#  'costs,\tenhanced\tloyalty\tprogram\treciprocity\tand\tcooperation\tin\tother\tareas.\tAmerican\tand\tits\tjoint\tbusiness\tpartners\treceived\tregulatory\tapproval\tto\tenter',
#  'into\t these\t cooperation\t agreements.\t Joint\t business\t agreements\t have\t become\t a\t common\t approach\t among\t major\t carriers\t to\t address\t key\t regulatory',
#  'restrictions\ttypically\tapplicable\tto\tinternational\tairline\tservice,\tincluding\tlimitations\ton\tthe\tforeign\townership\tof\tairlines\tand\tnational\tlaws\tprohibiting\tforeign',
#  'airlines\t from\t carrying\t passengers\t beyond\t specific\t gateway\t cities.\t Our\t competitors,\t including\t Delta\tAir\t Lines\t and\t United\tAirlines,\t are\t party\t to\t similar',
#  'arrangements.',
#  '',
#  'The\tbusiness\trelationship\tunder\tthe\ttransatlantic\tjoint\tbusiness\tbenefits\tfrom\ta\tgrant\tof\tantitrust\timmunity\tfrom\tthe\tU.S.\tDepartment\tof\tTransportation',
#  '(DOT)\tand\twas\treviewed\tby\t the\tEuropean\tCommission\t(EC)\t in\tJuly\t2010.\t In\tconnection\twith\t this\t review,\twe\tprovided\tcertain\tcommitments\t to\t the\tEC',
#  'regarding,\t among\t other\t things,\t the\t availability\t of\t take-off\t and\t landing\t slots\t at\t London\t Heathrow\t (LHR)\t or\t London\t Gatwick\t (LGW)\t airports.\t The',
#  'commitments\taccepted\tby\tthe\tEC\twere\tbinding\tfor\t10\tyears.\tIn\tOctober\t2018,\tin\tanticipation\tof\tthe\texit\tof\tthe\tUnited\tKingdom\tfrom\tthe\tEuropean\tUnion',
#  '(EU),',
#  '',
#  '8',
#  '',
#  '',
#  '',
#  'Table\tof\tContents',
#  '',
#  'commonly\t referred\t to\t as\tBrexit,\t and\t the\t expiry\t of\t the\tEC\t commitments\t in\t July\t 2020,\t the\tUnited\tKingdom\tCompetition\t and\tMarkets\tAuthority\t (CMA)',
#  'opened\tan\t investigation\t into\t the\t transatlantic\t joint\tbusiness.\tWe\tcontinue\t to\t fully\tcooperate\twith\t the\tCMA\tand,\t in\tSeptember\t2020,\t the\tCMA\tadopted',
#  'interim\tmeasures\t that\teffectively\textend\t the\tEC\tcommitments\t for\tan\tadditional\t three\tyears\tuntil\tMarch\t2024\t in\t light\t of\t the\tuncertainty\t created\tby\t the',
#  'COVID-19\t pandemic.\t The\t CMA\t plans\t to\t complete\t its\t investigation\t before\t the\t interim\tmeasures\t expire.\t In\t December\t 2020,\t the\t DOT\t issued\t its\t final',
#  'approval\t for\t the\t inclusion\tof\tAer\tLingus,\twhich\t is\towned\tby\t the\tparent\tcompany\tof\tBritish\tAirways\tand\t Iberia,\t into\t the\t transatlantic\t joint\tbusiness\tand',
#  'granted\tantitrust\timmunity.',
#  '',
#  'Marketing\tRelationships',
#  'To\t improve\taccess\t to\teach\tother’s\tmarkets,\t various\tU.S.\tand\t foreign\tair\t carriers,\t including\tAmerican,\thave\testablished\tmarketing\tagreements\twith',
#  '',
#  'other\t airlines.\t These\t marketing\t agreements\t generally\t provide\t enhanced\t customer\t choice\t by\t means\t of\t an\t expanded\t network\t with\t reciprocal\t loyalty',
#  'program\t participation\t and\t joint\t sales\t cooperation.\tAs\t of\t December\t 31,\t 2020,\tAmerican\t had\t codeshare\t and/or\t loyalty\t program\t relationships\t with\tAer',
#  'Lingus,\tAir\tTahiti\tNui,\tAlaska\tAirlines,\tBritish\tAirways,\tCape\tAir,\tCathay\tPacific,\tChina\tSouthern\tAirlines\tCompany\tLimited\t(China\tSouthern\tAirlines),\tEL',
#  'AL\tIsrael\tAirlines,\tEtihad\tAirways,\tFiji\tAirways,\tFinnair,\tGOL,\tGulf\tAir,\tHawaiian\tAirlines,\tIberia,\tInterjet\tAirlines,\tJapan\tAirlines,\tJetstar\tAirways,\tJetstar',
#  'Japan,\tJetBlue\tAirways\tCorporation\t(JetBlue),\tKorean\tAir\tLines,\tMalaysia\tAirlines,\tQantas,\tQatar\tAirways,\tRoyal\tAir\tMaroc,\tRoyal\tJordanian,\tS7\tAirlines,',
#  'Seaborne\tAirlines,\tSriLankan\tAirlines\tand\tVueling\tAirlines.',
#  '',
#  'In\t 2020,\t we\t entered\t into\t an\t expanded\tmarketing\t relationship\t with\tAlaska\tAirlines.\t This\t arrangement,\t once\t implemented,\t will\t expand\t our\t existing',
#  'codeshare\t relationship,\t including\t codeshare\t on\t certain\t of\t our\t international\t routes\t from\t Seattle-Tacoma\t International\tAirport\t (SEA)\t and\t Los\tAngeles',
#  'International\tAirport\t (LAX),\t and\twill\t provide\t for\t reciprocal\t loyalty\t program\tbenefits\t and\t shared\t lounge\t access.\tPursuant\t to\t federal\t law,\tAmerican\t and',
#  'Alaska\tAirlines\tsubmitted\t this\tproposed\tarrangement\t to\t the\tDOT\tfor\t review.\tAfter\t the\tDOT\tallowed\tthe\treview\tperiod\t to\texpire\twith\tno\t further\tactions,',
#  'American\tand\tAlaska\tAirlines\tcommenced\timplementation\tof\tthis\tarrangement.',
#  '',
#  'Also,\t in\t2020,\twe\tannounced\tour\t intention\t to\tenter\t into\ta\tmarketing\t relationship\twith\tJetBlue.\tThis\tarrangement,\tonce\t implemented,\twill\t include\tan',
#  'alliance\tagreement\twith\t reciprocal\t codesharing\ton\tdomestic\t and\t international\t routes\t from\tNew\tYork\t (John\tF.\tKennedy\t International\tAirport\t (JFK),\t La',
#  'Guardia\tAirport\t (LGA),\t and\tNewark\t Liberty\t International\tAirport\t (EWR))\t and\tBoston\t Logan\t International\tAirport\t (BOS),\t and\twill\t provide\t for\t reciprocal',
#  'loyalty\tprogram\tbenefits.\tThe\tarrangement\tdoes\tnot\tinclude\tJetBlue’s\tfuture\ttransatlantic\tflying.\tPursuant\tto\tfederal\tlaw,\tAmerican\tand\tJetBlue\tsubmitted',
#  'this\tproposed\talliance\tarrangement\tto\tthe\tDOT\tfor\treview.\tAfter\tAmerican,\tJetBlue\tand\tthe\tDOT\tagreed\tto\ta\tseries\tof\tcommitments,\tthe\tDOT\tterminated',
#  'its\treview\tof\tthe\tproposed\talliance.\tThe\tcommitments\tinclude\tgrowth\tcommitments\tto\tensure\tcapacity\texpansion,\tslot\tdivestitures\tat\tJFK\tand\tat\tRonald',
#  'Reagan\tWashington\tNational\tAirport\t(DCA)\tnear\tWashington,\tD.C.\tand\tantitrust\tcompliance\tmeasures.\tBeyond\tthis\tagreement\twith\tthe\tDOT,\tAmerican',
#  'and\tJetBlue\twill\talso\tbe\trefraining\tfrom\tcertain\tkinds\tof\tcoordination\ton\tcertain\tcity\tpair\tmarkets.\tIn\taddition\tto\tthe\tDOT\treview,\tthe\tU.S.\tDepartment\tof',
#  'Justice\t (DOJ)\t and\t the\t New\tYork\tAttorney\tGeneral,\t the\tMassachusetts\tAttorney\tGeneral,\t and\t the\tAttorneys\tGeneral\t of\t certain\t other\t state\t and\t local',
#  'jurisdictions\tare\tinvestigating\tthis\tproposed\talliance,\twhich\tremains\tongoing.\tAmerican\tand\tJetBlue\tintend\tto\tcooperate\twith\tthose\tinvestigations,\tbut\tare',
#  'proceeding\twith\tplans\tto\timplement\tthis\talliance.',
#  '',
#  'Loyalty\tProgram',
#  'Our\t loyalty\t program,\tAAdvantage ,\t was\t established\t to\t develop\t passenger\t loyalty\t by\t offering\t awards\t to\t travelers\t for\t their\t continued\t patronage.',
#  '',
#  'AAdvantage\twas\tnamed\tBest\tElite\tProgram\tin\tthe\tAmericas\tfor\t the\tninth\tconsecutive\tyear\tat\t the\t2020\tFreddie\tAwards,\twhich\tare\tannual\tawards\tthat',
#  'recognize\t the\t world’s\t most\t outstanding\t frequent\t travel\t programs.\t AAdvantage\t members\t earn\t mileage\t credits\t by\t flying\t on\t American,\t any\toneworld',
#  'Alliance\tairline\tor\tother\tpartner\tairlines.\tFor\tevery\tdollar\tspent\tby\tflying\ton\tAmerican,\tmembers\tearn\tfive\tmileage\tcredits,\tbut\tGold,\tPlatinum,\tPlatinum\tPro',
#  'and\tExecutive\tPlatinum\telite\tstatus\tholders\tearn\tadditional\tbonus\tmileage\tcredits\tof\t40%,\t60%,\t80%\tand\t120%,\trespectively.\tMembers\talso\tearn\tmileage',
#  'credits\tby\tusing\tthe\tservices\tof\tover\t1,000\tprogram\tparticipants,\tsuch\tas\tthe\tCiti\tand\tBarclaycard\tUS\tco-branded\tcredit\tcards,\tand\tcertain\thotels\tand\tcar',
#  'rental\tcompanies.',
#  '',
#  'All\t travel\t on\t eligible\t tickets\t counts\t toward\t qualification\t for\t elite\t status\t in\t the\tAAdvantage\t program.\t Mileage\t credits\t can\t be\t redeemed\t for\t free\t or',
#  'upgraded\ttravel\ton\tAmerican\tand\tparticipating\tairlines,\tmembership\tto\tour\tAdmirals\tClub \tor\tfor\tother\tnon-flight\tawards\tfrom\tour\tprogram\tparticipants.',
#  'Most\ttravel\tawards\tare\tsubject\tto\tcapacity-controlled\tseating.\tA\tmember’s\tmileage\tcredit\tgenerally\tdoes\tnot\texpire\tas\tlong\tas\tthat\tmember\thas\tany\ttype\tof',
#  'qualifying\tactivity\tat\tleast\tonce\tevery\t18\tmonths.\tIn\tresponse\tto\tthe\tCOVID-19\tpandemic,\twe\tsuspended\tthe\texpiration\tof\tmileage\tcredits\tthrough\tJune',
#  '30,\t2021\tand\teliminated\tmileage\treinstatement\tfees\tfor\tcanceled\taward\ttickets.\tElite\tmembers\tcan\tenjoy\tadditional',
#  '',
#  '®',
#  '',
#  '®',
#  '',
#  '9',
#  '',
#  '',
#  '',
#  'Table\tof\tContents',
#  '',
#  'benefits\tof\t the\tAAdvantage\tprogram,\t including\tcomplimentary\tupgrades,\tchecked\tbags,\tand\tPreferred\tand\tMain\tCabin\tExtra\tseats,\tas\twell\tas\tpriority',
#  'check-in,\tsecurity,\tboarding\tand\tbaggage\tdelivery.\tWe\talso\tmade\tit\teasier\tfor\ttop-tier\tcustomers\tto\tearn\tAAdvantage\telite\tstatus\tin\t2020\tand\t2021\tand',
#  'extended\t2020\tAAdvantage\tstatus\tinto\tearly\t2022\tfor\tall\tmembers.',
#  '',
#  'Under\tour\tagreements\twith\tAAdvantage\tmembers\tand\tprogram\tpartners,\twe\treserve\tthe\tright\tto\tchange\tthe\tterms\tof\tthe\tAAdvantage\tprogram\tat\tany',
#  'time\tand\twithout\tnotice,\tand\tmay\tend\tthe\tprogram\twith\tsix\tmonths’\tnotice.\tProgram\trules,\tpartners,\tspecial\toffers,\tawards\tand\trequisite\tmileage\tlevels\tfor',
#  'awards\tare\tsubject\tto\tchange.',
#  '',
#  'During\t2020,\tour\tmembers\tredeemed\tapproximately\t7\tmillion\tawards,\tincluding\ttravel\tredemptions\tfor\tflights\tand\tupgrades\ton\tAmerican\tand\tother\tair',
#  'carriers,\tas\twell\tas\t redemption\tof\tcar\tand\thotel\tawards,\tclub\tmemberships\tand\tmerchandise.\tApproximately\t6%\tof\tour\t2020\t total\t revenue\tpassenger',
#  'miles\tflown\twere\tfrom\taward\ttravel.',
#  '',
#  'See\tPart\t II,\t Item\t 7.\tManagement’s\t Discussion\t and\tAnalysis\t of\t Financial\t Condition\t and\tResults\t of\tOperations\t –\t “ Critical\tAccounting\t Policies\t and',
#  'Estimates”\tfor\tmore\tinformation\ton\tour\tloyalty\tprogram.',
#  '',
#  'Industry\tCompetition',
#  'Domestic',
#  'The\tmarkets\t in\twhich\twe\toperate\tare\thighly\tcompetitive.\tOn\tmost\tof\tour\tdomestic\tnonstop\t routes,\twe\t face\tcompeting\tservice\t from\tother\tdomestic',
#  '',
#  'airlines,\t including\t major\t network\t airlines,\t low-cost\t carriers\t and\t ultra-low-cost\t carriers\t such\t as\tAlaska\tAirlines,\tAllegiant\tAir,\t Delta\tAir\t Lines,\t Frontier',
#  'Airlines,\t Hawaiian\tAirlines,\t JetBlue,\t Southwest\tAirlines,\t Spirit\tAirlines\t and\tUnited\tAirlines.\t Between\t cities\t that\t require\t a\t connection,\t where\t the\tmajor',
#  'airlines\t compete\t via\t their\t respective\t hubs,\t competition\t is\t significant.\t In\t addition,\twe\t face\t competition\t on\t some\tof\t our\t connecting\t routes\t from\tairlines',
#  'operating\tpoint-to-point\tservice\ton\tsuch\troutes.\tWe\talso\tcompete\twith\tall-cargo\tand\tcharter\tairlines\tand,\tparticularly\ton\tshorter\tsegments,\tground\tand\trail',
#  'transportation.',
#  '',
#  'On\tall\tof\tour\troutes,\tpricing\tdecisions\tare\taffected,\t in\t large\tpart,\tby\t the\tneed\tto\tmeet\tcompetition\t from\tother\tairlines.\tPrice\tcompetition\toccurs\ton\ta',
#  'market-by-market\tbasis\tthrough\tprice\tdiscounts,\tchanges\tin\tpricing\tstructures,\tfare\tmatching,\ttargeted\tpromotions\tand\tloyalty\tprogram\tinitiatives.\tAirlines',
#  'typically\tuse\tdiscounted\tfares\tand\tother\tpromotions\tto\tstimulate\ttraffic\tduring\tnormally\tweak\ttravel\tperiods,\twhen\tthey\tbegin\tservice\tto\tnew\tcities,\twhen',
#  'they\thave\texcess\tcapacity,\tto\tgenerate\tcash\tflow,\tto\tmaximize\trevenue\tper\tavailable\tseat\tmile\tor\tto\testablish,\tincrease\tor\tpreserve\tmarket\tshare.\tMost',
#  'airlines\twill\tquickly\tmatch\tprice\treductions\tin\ta\tparticular\tmarket,\tand\twe\thave\toften\telected\tto\tmatch\tdiscounted\tor\tpromotional\tfares\tinitiated\tby\tother\tair',
#  'carriers\tin\tcertain\tmarkets\tin\torder\tto\tcompete\tin\tthose\tmarkets.\tIn\taddition,\tso-called\tultra-low-cost\tcarriers,\tsuch\tas\tAllegiant\tAir,\tFrontier\tAirlines\tand',
#  'Spirit\t Airlines,\t compete\t in\t many\t of\t the\t markets\t in\t which\t we\t operate,\t competition\t from\t these\t carriers\t is\t increasing\t and\t several\t new\t entrants\t have',
#  'announced\ttheir\tintention\tto\tstart\tup\tnew\tultra-low-cost\tcarriers.',
#  '',
#  'In\taddition\tto\tprice\tcompetition,\tairlines\tcompete\tfor\tmarket\tshare\tby\tincreasing\tthe\tsize\tof\ttheir\troute\tsystem\tand\tthe\tnumber\tof\tmarkets\tthey\tserve.',
#  'The\tAmerican\tEagle\tregional\tcarriers\tincrease\tthe\tnumber\tof\tmarkets\twe\tserve\tby\tflying\tto\tsmaller\tmarkets\tand\tproviding\tconnections\tat\tour\thubs.\tMany',
#  'of\tour\tcompetitors\talso\town\tor\thave\tagreements\twith\tregional\tairlines\tthat\tprovide\tsimilar\tservices\tat\ttheir\thubs\tand\tother\tlocations.\tWe\talso\tcompete\ton',
#  'the\tbasis\tof\tscheduling\t(frequency\tand\tflight\ttimes),\tavailability\tof\tnonstop\tflights,\ton-time\tperformance,\ttype\tof\tequipment,\tcabin\tconfiguration,\tamenities',
#  'provided\tto\tpassengers,\tloyalty\tprograms,\tthe\tautomation\tof\ttravel\tagent\treservation\tsystems,\tonboard\tproducts,\thealth\tand\tsafety\tand\tother\tservices.',
#  '',
#  'International',
#  'In\taddition\t to\tour\textensive\tdomestic\tservice,\twe\tprovide\t international\tservice\t to\tCanada,\tMexico,\t the\tCaribbean,\tCentral\tand\tSouth\tAmerica,\tAsia,',
#  '',
#  'Europe,\tAustralia\tand\tNew\tZealand.\tIn\tproviding\tinternational\tair\ttransportation,\twe\tcompete\twith\tother\tU.S.\tairlines,\tforeign\tinvestor-owned\tairlines\tand',
#  'foreign\t state-owned\t or\t state-affiliated\t airlines.\t Before\t the\tCOVID-19\t pandemic,\t competition\t had\t been\t increasing\t from\t foreign\t state-owned\t and\t state-',
#  'affiliated\tairlines\tin\tthe\tGulf\tregion.\tThese\tcarriers\thave\tlarge\tnumbers\tof\tinternational\twidebody\taircraft\tin\tservice\tand\ton\torder\tand\thad\tbeen\tincreasing',
#  'service\tto\tthe\tU.S.\tfrom\tlocations\tboth\tin\tand\toutside\tthe\tMiddle\tEast.\tService\tto\tand\tfrom\tlocations\toutside\tof\tthe\tMiddle\tEast\twas\tprovided\tby\tsome\tof',
#  'these\tcarriers\tunder\t so-called\t “fifth\t freedom”\t rights\tpermitted\tunder\t international\t treaties\twhich\tallow\tservice\t to\tand\t from\tstopover\tpoints\tbetween\tan',
#  'airline’s\thome\tcountry\tand\tthe\tultimate\tdestination.\tSuch\tflights,\tsuch\tas\ta\tstopover\tin\tEurope\ton\tflights\tto\tthe\tUnited\tStates,\tallow\tthe\tcarrier\tto\tsell\ttickets',
#  'for\ttravel\tbetween\tthe\tstopover\tpoint\tand\tthe\tUnited\tStates\tin\tcompetition\twith\tservice\tprovided\tby\tus.\tWe\tbelieve\tthese\tstate-owned\tand\tstate-affiliated',
#  'carriers\tin\tthe\tGulf\tregion,\tincluding\ttheir\taffiliated\tcarriers,\tbenefit\tfrom\tsignificant\tgovernment\tsubsidies,',
#  '',
#  '10',
#  '',
#  '',
#  '',
#  'Table\tof\tContents',
#  '',
#  'which\thave\tallowed\t them\t to\tgrow\tquickly,\t reinvest\t in\t their\t product\tand\texpand\t their\t global\t presence.\tWe\texpect\t this\t to\t continue\tafter\t the\tCOVID-19',
#  'pandemic\tsubsides.\tCompetition\thad\talso\tbeen\tincreasing\tfrom\tlow-cost\tairlines\texecuting\tinternational\tlong-haul\texpansion\tstrategies,\ta\ttrend\twe\talso',
#  'expect\tto\tcontinue\tafter\tthe\tCOVID-19\tpandemic\tsubsides\tand\tthe\tdelivery\tof\tplanned,\tlong-range\tnarrowbody\taircraft\tcommences.',
#  '',
#  'In\torder\t to\t increase\tour\tability\t to\tcompete\t for\t international\tair\t transportation\tservice,\twhich\t is\tsubject\t to\textensive\tgovernment\t regulation,\tU.S.\tand',
#  'foreign\tcarriers\thave\tentered\tinto\tbilateral\tand\tmultilateral\tmarketing\trelationships,\talliances,\tcooperation\tagreements\tand\tjoint\tbusiness\tagreements\tto',
#  'exchange\ttraffic\tamong\teach\tother’s\tflights\tand\troute\tnetworks.\tSee\t“Distribution\tand\tMarketing\tAgreements ”\tabove\tfor\tfurther\tdiscussion.',
#  '',
#  'Our\tPeople',
#  'The\tairline\tbusiness\t is\t labor\t intensive,\tand\tour\tteam\tmembers\tare\tour\tmost\t important\tasset.\tThe\toperational\tcomplexity\tof\tour\tbusiness\trequires\ta',
#  '',
#  'diverse\tteam\tof\tpersonnel\ttrained\tand\texperienced\tin\ta\tvariety\tof\ttechnical\tareas\tsuch\tas\tflight\toperations,\tground\toperations,\tsafety\tand\tmaintenance,',
#  'customer\tservice,\tand\tairline\tscheduling\tand\tplanning.\tWe\tbelieve\tthat\tif\twe\tcreate\tan\tenvironment\twhere\tour\tteam\tmembers\tfeel\tsupported,\tthey\twill\ttake',
#  'care\tof\tour\tcustomers\tand\tthereby\tsupport\tthe\tsuccess\tof\tour\tbusiness.\tTo\tdo\tthis,\twe\tmust\tcontinue\tto\tbuild\ta\tdiverse\tand\tinclusive\tenvironment,\thelping',
#  'all\tteam\tmembers\treach\ttheir\tfull\tpotential\tand\tproviding\tthem\twith\tthe\tright\tresources\tand\tsupport.',
#  '',
#  'Talent\tDevelopment',
#  'We\tgive\tour\tteam\tmembers\tthe\ttools,\ttraining\tand\tresources\tthey\tneed\tto\tdo\ttheir\tbest\twork\tand\tstay\ttrue\tto\tour\tpurpose\t–\tcaring\tfor\tpeople\ton\tlife’s',
#  '',
#  'journey.\tWe\thave\ta\tsuite\tof\tprograms\taimed\tat\thelping\tour\tpeople\tdevelop\tthe\tskills\tand\texperience\tto\tsucceed\tin\ttheir\troles\tand\tbuild\trewarding,\tlong-',
#  'term\tcareers\twithin\tour\tcompany.\tAdditionally,\twe’ve\tpartnered\twith\t leading\tonline\t learning\tplatforms\t to\tmake\tprofessional\tdevelopment\tavailable\ton-',
#  'demand\tto\tall\tour\tteam\tmembers.',
#  '',
#  'Diversity,\tEquity\tand\tInclusion',
#  'Cultivating\tan\tenvironment\tthat\tcelebrates\tdiversity,\tequity\tand\tinclusion\t(DEI)\tis\ta\ttop\tpriority\tfor\tus,\tand\twe\tseek\tto\tcreate\ta\tworkplace\twhere\tdiverse',
#  '',
# ...
#  '',
#  '(FAA)\texercise\tsignificant\tregulatory\tauthority\tover\tair\tcarriers.',
#  '',
#  'The\tDOT,\tamong\tother\tthings,\toversees\tand\tregulates\tdomestic\tand\tinternational\tcodeshare\tagreements,\t international\troute\tauthorities,\tcompetition',
#  'and\tconsumer\tprotection\tmatters\tsuch\tas\tadvertising,\tdenied\tboarding\tcompensation\tand\tbaggage\tliability.\tThe\tAntitrust\tDivision\tof\tthe\tDOJ,\talong\twith',
#  'the\tDOT\tin\tcertain\tinstances,\thave\tjurisdiction\tover\tairline\tantitrust\tmatters.',
#  '',
#  'The\t FAA\t similarly\t exercises\t safety\t oversight\t and\t regulates\tmost\t operational\tmatters\t of\t our\t business,\t including\t how\twe\t operate\t and\tmaintain\t our',
#  'aircraft.\t FAA\t requirements\t cover,\t among\t other\t things,\t required\t technology\t and\t necessary\t onboard\t equipment;\t systems,\t procedures\t and\t training',
#  'necessary\t to\tensure\t the\tcontinuous\tairworthiness\tof\t our\t fleet\tof\t aircraft;\t safety\tmeasures\tand\tequipment;\t crew\tscheduling\t limitations\tand\texperience',
#  'requirements;\t and\tmany\tother\t technical\t aspects\tof\t airline\toperations.\tAdditionally,\t our\t pilots\t and\tother\t employees\tare\t subject\t to\t rigorous\t certification',
#  'standards,\tand\tour\tpilots\tand\tother\tcrew\tmembers\tmust\tadhere\tto\tflight\ttime\tand\trest\trequirements.\tIn\t2021,\tthe\tFAA\tis\texpected\tto\tissue\ta\tnumber\tof',
#  'rules\tthat\twill\timpact\tus,\tincluding\tregulations\tmandating\tcertain\trest\trequirements\tfor\tflight\tattendants.',
#  '',
#  'The\tFAA\talso\tcontrols\tthe\tnational\tairspace\tsystem,\tincluding\toperational\trules\tand\tfees\tfor\tair\ttraffic\tcontrol\t(ATC)\tservices.\tThe\tefficiency,\treliability',
#  'and\tcapacity\tof\tthe\tATC\tnetwork\thas\ta\tsignificant\timpact\ton\tour\tcosts\tand\ton\tthe\ttimeliness\tof\tour\toperations.',
#  '',
#  'The\tU.S.\tPostal\tService\thas\tjurisdiction\tover\tcertain\taspects\tof\tthe\ttransportation\tof\tmail\tand\trelated\tservices.',
#  '',
#  '15',
#  '',
#  '',
#  '',
#  'Table\tof\tContents',
#  '',
#  'Airport\tAccess\tand\tOperations',
#  'Domestically,\tany\tU.S.\tairline\tauthorized\tby\tthe\tDOT\tis\tgenerally\tfree\tto\toperate\tscheduled\tpassenger\tservice\tbetween\tany\ttwo\tpoints\twithin\tthe\tU.S.',
#  '',
#  'and\tits\tterritories,\twith\tthe\texception\tof\tcertain\tairports\tthat\trequire\tlanding\tand\ttake-off\trights\tand\tauthorizations\t(slots)\tand\tother\tfacilities,\tand\tcertain',
#  'airports\tthat\timpose\tgeographic\tlimitations\ton\toperations\tor\tcurtail\toperations\tbased\ton\tthe\ttime\tof\tday.\tOperations\tat\tthree\tmajor\tdomestic\tairports\twe',
#  'serve\t (JFK\t and\t LGA\t in\t New\t York\t City,\t and\t DCA\t near\t Washington,\t D.C.)\t and\t many\t foreign\t airports\t we\t serve\t (including\t LHR)\t are\t regulated\t by',
#  'governmental\tentities\tthrough\tallocations\tof\tslots\tor\tsimilar\tregulatory\tmechanisms\tthat\tlimit\tthe\trights\tof\tcarriers\tto\tconduct\toperations\tat\tthose\tairports.',
#  'Each\t slot\t represents\t the\t authorization\t to\t land\t at\t or\t take\t off\t from\t the\t particular\t airport\t during\t a\t specified\t time\t period.\t In\t addition\t to\t slot\t restrictions,',
#  'operations\t at\t DCA\t and\t LGA\t are\t also\t limited\t based\t on\t a\t so-called\t “perimeter\t rule”\t which\t generally\t limits\t the\t stage\t length\t of\t the\t flights\t that\t can\t be',
#  'operated\tfrom\tthose\tairports\tto\t1,250\tand\t1,500\tmiles,\trespectively.',
#  '',
#  'Our\tability\tto\tprovide\tservice\tcan\talso\tbe\timpaired\tat\tairports,\tsuch\tas\tChicago\tO’Hare\tInternational\tAirport\t(ORD)\tand\tLAX\twhere\tthe\tairport\tgate\tand',
#  'other\tfacilities\tare\tcurrently\tinadequate\tto\taccommodate\tall\tof\tthe\tservice\tthat\twe\twould\tlike\tto\tprovide,\tor\tairports\tsuch\tas\tDallas\tLove\tField\tAirport\twhere',
#  'we\thave\tno\taccess\tto\tgates\tat\tall.',
#  '',
#  'Existing\t law\talso\tpermits\tdomestic\t local\tairport\tauthorities\t to\t implement\tprocedures\tand\t impose\trestrictions\tdesigned\t to\tabate\tnoise,\tprovided\tsuch',
#  'procedures\tand\trestrictions\tdo\tnot\tunreasonably\t interfere\twith\t interstate\tor\tforeign\tcommerce\tor\tthe\tnational\ttransportation\tsystem.\tIn\tsome\tinstances,',
#  'these\trestrictions\thave\tcaused\tcurtailments\tin\tservice\tor\tincreases\tin\toperating\tcosts.',
#  '',
#  'Airline\tFares,\tTaxes\tand\tUser\tFees',
#  'Airlines\tare\tpermitted\t to\testablish\t their\town\tdomestic\t fares\twithout\tgovernmental\t regulation.\tThe\tDOT\tmaintains\tauthority\tover\tcertain\t international',
#  '',
#  'fares,\trates\tand\tcharges,\tbut\tonly\tapplies\tthis\tauthority\ton\ta\tlimited\tbasis.\tIn\taddition,\tinternational\tfares\tand\trates\tare\tsometimes\tsubject\tto\tthe\tjurisdiction',
#  'of\tthe\tgovernments\tof\tthe\tforeign\tcountries\twhich\twe\tserve.',
#  '',
#  'Airlines\tare\tobligated\tto\tcollect\ta\tfederal\texcise\ttax,\tcommonly\treferred\tto\tas\tthe\t“ticket\ttax,”\ton\tdomestic\tand\tinternational\tair\t transportation,\tand\tto',
#  'collect\tother\ttaxes\tand\tcharge\tother\tfees,\tsuch\tas\tforeign\ttaxes,\tsecurity\tfees\tand\tpassenger\tfacility\tcharges.\tAlthough\tthese\ttaxes\tand\tfees\tare\tnot\tour',
#  'operating\texpenses,\tthey\trepresent\tan\tadditional\tcost\tto\tour\tcustomers.\tThese\ttaxes\tand\tfees\tare\tsubject\tto\tincrease\tfrom\ttime\tto\ttime.\tThe\tCARES\tAct',
#  'provided\t for\ta\t temporary\t tax\tholiday\t from\tcollecting\tand\t remitting\tcertain\tgovernment\t ticket\t taxes\t for\t tickets\tpurchased\tbetween\tMarch\t28,\t2020\tand',
#  'December\t31,\t2020.',
#  '',
#  'DOT\tPassenger\tProtection\tRules',
#  'The\tDOT\tregulates\tairline\tinteractions\twith\tpassengers\tthrough\tthe\tticketing\tprocess,\tat\tthe\tairport\tand\ton\tboard\tthe\taircraft.\tAmong\tother\tthings,\tthese',
#  '',
#  'regulations\tgovern\thow\tour\t fares\tare\tdisplayed\tonline,\t required\tcustomer\tdisclosures,\taccess\tby\tdisabled\tpassengers,\thandling\tof\t long\tonboard\t flight',
#  'delays\tand\treporting\tof\tmishandled\tbags.\tIn\t2021,\tthe\tDOT\tis\texpected\tto\timplement\ta\tnumber\tof\tnew\tregulations\tthat\twill\timpact\tus,\tincluding\tdisability',
#  'rules\tfor\taccessible\tlavatories\tand\twheelchair\tassistance,\tand\trefunds\tfor\tchecked\tbag\tfees\tin\tthe\tevent\tof\tcertain\tdelays\tin\tdelivery.',
#  '',
#  'International',
#  'International\tair\t transportation\t is\tsubject\t to\textensive\tgovernment\tregulation,\t including\taviation\tagreements\tbetween\tthe\tU.S.\tand\tother\tcountries\tor',
#  '',
#  'governmental\tauthorities,\tsuch\tas\tthe\tEU\tand\tthe\tUnited\tKingdom.\tMoreover,\tour\talliances\twith\t international\tcarriers\tmay\tbe\tsubject\t to\tthe\t jurisdiction',
#  'and\t regulations\t of\t various\t foreign\t agencies.\t The\t U.S.\t government\t has\t negotiated\t “open\t skies”\t agreements\t with\t 130\t trading\t partners,\t which\t allow',
#  'unrestricted\troute\tauthority\taccess\tbetween\tthe\tU.S.\tand\tthe\tforeign\tmarkets.\tWhile\tthe\tU.S.\thas\tworked\tto\tincrease\tthe\tnumber\tof\tcountries\twith\twhich',
#  'open\tskies\tagreements\tare\tin\teffect,\ta\tnumber\tof\tmarkets\timportant\tto\tus,\tincluding\tChina,\tdo\tnot\thave\topen\tskies\tagreements.',
#  '',
#  'In\t addition,\t foreign\t countries\t impose\t passenger\t protection\t rules,\twhich\t are\t analogous\t to,\t and\t often\tmeet\t or\t exceed\t the\t requirements\t of,\t the\tDOT',
#  'passenger\tprotection\t rules\tdiscussed\tabove.\t In\t cases\twhere\t these\t foreign\t requirements\texceed\t the\tDOT\t rules,\twe\tmay\tbear\tadditional\t burdens\tand',
#  'liabilities.\tFurther,\tvarious\tforeign\tairport\tauthorities\timpose\tnoise\tand\tcurfew\trestrictions\tat\ttheir\tlocal\tairports.',
#  '',
#  '16',
#  '',
#  '',
#  '',
#  'Table\tof\tContents',
#  '',
#  'Security',
#  'Since\tshortly\tafter\tthe\tevents\tof\tSeptember\t11,\t2001,\tsubstantially\tall\taspects\tof\tcivil\taviation\tsecurity\tin\tthe\tU.S.\tor\taffecting\tU.S.\tcarriers\thave\tbeen',
#  '',
#  'controlled\tor\t regulated\tby\t the\t federal\tgovernment\t through\t the\tTransportation\tSecurity\tAdministration\t (TSA).\tRequirements\t include\t flight\tdeck\tsecurity;',
#  'carriage\tof\t federal\tair\tmarshals\tat\tno\tcharge;\tenhanced\tsecurity\t screening\tof\tpassengers,\tbaggage,\t cargo,\tmail,\t employees\tand\tvendors;\t fingerprint-',
#  'based\tbackground\tchecks\tof\tall\temployees\tand\tvendor\temployees\twith\taccess\tto\tsecure\tareas\tof\tairports;\tand\tthe\tprovision\tof\tcertain\tpassenger\tdata\tto',
#  'the\t federal\tgovernment\tand\tother\t international\tborder\tsecurity\tauthorities,\t for\tsecurity\tand\t immigration\tcontrols.\tFunding\t for\t the\tTSA\t is\tprovided\tby\ta',
#  'combination\tof\tair\tcarrier\t fees,\tpassenger\t fees\tand\t taxpayer\t funds.\tCustoms\tand\tBorder\tProtection,\twhich,\t like\t the\tTSA,\t is\tpart\tof\t the\tDepartment\tof',
#  'Homeland\tSecurity,\talso\tpromulgates\trequirements,\tperforms\tservices\tand\tcollects\t fees\t that\t impact\tour\tprovision\tof\tservices.\tAdditionally,\twe\thave\tat',
#  'times\tfound\tit\tnecessary\tor\tdesirable\tto\tmake\tsignificant\texpenditures\tto\tcomply\twith\tsecurity-related\trequirements\twhile\tseeking\tto\treduce\ttheir\timpact\ton',
#  'our\tcustomers,\tsuch\tas\texpenditures\tfor\tautomated\tsecurity\tscreening\tlines\tat\tairports.\tOur\tinternational\tservice\tfurther\trequires\tus\tto\tcomply\twith\tthe\tcivil',
#  'aviation\tsecurity\tregimes\timposed\tat\tthe\tforeign\tairports\twe\tserve.',
#  '',
#  'Environmental\tMatters',
#  'Environmental\tRegulation',
#  'The\t airline\t industry\t is\t subject\t to\t various\t laws\t and\t government\t regulations\t concerning\t environmental\tmatters\t in\t the\tU.S.\t and\t other\t countries.\tU.S.',
#  '',
#  'federal\t laws\t that\t have\t a\t particular\t impact\t on\t our\t operations\t include\t the\tAirport\t Noise\t and\t Capacity\tAct\t of\t 1990,\t the\t Clean\tAir\t Act,\t the\t Resource',
#  'Conservation\tand\tRecovery\tAct,\tthe\tClean\tWater\tAct,\tthe\tSafe\tDrinking\tWater\tAct\tand\tthe\tComprehensive\tEnvironmental\tResponse,\tCompensation\tand',
#  'Liability\t Act\t (Superfund\t Act).\t The\t U.S.\t Environmental\t Protection\t Agency\t (EPA)\t and\t other\t federal\t agencies\t have\t been\t authorized\t to\t promulgate',
#  'regulations\tthat\thave\tan\timpact\ton\tour\toperations.\tIn\taddition\tto\tthese\tfederal\tactivities,\tvarious\tstates\thave\tbeen\tdelegated\tcertain\tauthorities\tunder\tthe',
#  'aforementioned\tfederal\tstatutes.\tMany\tstate\tand\tlocal\tgovernments\thave\tadopted\tenvironmental\tlaws\tand\tregulations\twhich\tare\tsimilar\tto\tor\tstricter\tthan',
#  'federal\trequirements.',
#  '',
#  'Revised\tunderground\tstorage\ttank\tregulations\tissued\tby\tthe\tEPA\tin\t2015\thave\taffected\tcertain\tairport\tfuel\thydrant\tsystems,\twith\tmodifications\tof\tsuch',
#  'systems\tneeded\tin\torder\tto\tcomply\twith\tapplicable\tportions\tof\tthe\trevised\tregulations.\tIn\taddition,\trelated\tto\tthe\tEPA\tand\tstate\tregulations\tpertaining\tto',
#  'storm\twater\tmanagement,\tseveral\tU.S.\tairport\tauthorities\tare\tactively\tengaged\tin\tefforts\tto\tlimit\tdischarges\tof\tdeicing\tfluid\tinto\tthe\tenvironment,\toften\tby',
#  'requiring\tairlines\tto\tparticipate\tin\tthe\tbuilding\tor\treconfiguring\tof\tairport\tdeicing\tfacilities.',
#  '',
#  'The\t environmental\t laws\t to\t which\t we\t are\t subject\t include\t those\t related\t to\t responsibility\t for\t potential\t soil\t and\t groundwater\t contamination.\t We\t are',
#  'conducting\tinvestigation\tand\tremediation\tactivities\tto\taddress\tsoil\tand\tgroundwater\tconditions\tat\tseveral\tsites,\tincluding\tairports\tand\tmaintenance\tbases.',
#  'We\tpresently\tanticipate\tthat\tthe\tongoing\tcosts\tof\tsuch\tactivities\twill\tnot\thave\ta\tmaterial\timpact\ton\tour\toperations.\tIn\taddition,\twe\thave\tbeen\tnamed\tas\ta',
#  'potentially\tresponsible\tparty\t(PRP)\tat\tcertain\tSuperfund\tsites.\tOur\talleged\tvolumetric\tcontributions\tat\tsuch\tsites\tare\trelatively\tsmall\tin\tcomparison\tto\ttotal',
#  'contributions\tof\t all\tPRPs.\tAccordingly,\twe\tpresently\t anticipate\t that\t any\t future\tpayments\tof\t costs\tat\t such\t sites\twill\t not\t have\ta\tmaterial\t impact\t on\tour',
#  'operations.',
#  '',
#  'We\t employ\t an\t environmental\t management\t system\t that\t provides\t a\t systematic\t approach\t for\t compliance\t with\t environmental\t regulations\t and',
#  'management\tof\ta\tbroad\trange\tof\tissues\tincluding\tair\temissions,\thazardous\twaste\tdisposal,\tunderground\ttanks,\tand\taircraft\twater\tquality.',
#  '',
#  'Aircraft\tEmissions\tand\tClimate\tChange\tRequirements',
#  'Efforts\tto\ttransition\tto\ta\tlow-carbon\tfuture\thave\tincreased\tthe\tfocus\tby\tglobal,\tregional\tand\tnational\tregulators\ton\tclimate\tchange\tand\tgreenhouse\tgas',
#  '',
#  '(GHG)\temissions.\tWe\thave\ttaken\ta\tnumber\tof\tactions\tthat\tmitigate\tthe\tGHG\temitted\tby\tour\toperations\tboth\ten\troute\tand\ton\tthe\tground,\tsuch\tas:',
#  '',
#  '• retiring\tolder,\tless\tfuel-efficient\taircraft\tand\treplacing\tthem\twith\tnew,\tmore\tfuel-efficient\taircraft,\tresulting\tin\tthe\tyoungest\tmainline\tfleet\tof',
#  'any\tU.S.\tnetwork\tcarrier;',
#  '',
#  '• reducing\t fuel\t consumption\t through\t operational\t initiatives\t such\t as\t single-engine\t taxi,\t optimal\t planned\t arrival\t fuel\t and\t our\t new\t flight',
#  'planning\tsystem;',
#  '',
#  '• entering\tinto\tan\tagreement\twith\ta\tleading\tproducer\tof\trenewable\tfuels\tto\tpurchase\tnine\tmillion\tgallons\tof\tsustainable\talternative\taircraft',
#  'fuel\tover\tthree\tyears;',
#  '',
#  '17',
#  '',
#  '',
#  '',
#  'Table\tof\tContents',
#  '',
#  '• working\twith\tthe\tFAA\tand\tvendors\tto\tfacilitate\tefficient\tairspace\tprocedures,\twhich\talso\treduces\taircraft\temissions;',
#  '',
#  '• updating\t our\t fleet\twith\t lightweight\t interiors\t including\t seats\t and\t furnishings\t and\t replacing\t existing\t cargo\t containers\twith\t lighter\tweight',
#  'versions;',
#  '',
#  '• replacing\tolder,\t inefficient\tground\tsupport\tequipment\twith\tnew,\tmore\t fuel-efficient\tground\tsupport\tequipment,\t including\talternative-fuel',
#  'and\telectric\tpowered\tequipment;',
#  '',
#  '• purchasing\trenewable\telectricity\tto\treduce\tindirect\temissions\tassociated\twith\tthe\tproduction\tof\tthe\tpower\twe\tconsume;\tand',
#  '',
#  '• obtaining\tcertification\tof\tcertain\tof\tour\tbuildings\t to\t the\tU.S.\tGreen\tBuilding\tCouncil’s\tLeadership\t in\tEnergy\tand\tEnvironmental\tDesign',
#  '(LEED)\tstandard.',
#  '',
#  'In\t addition,\t American\t is\t subject\t to\t the\t requirements\t of\t the\t Carbon\t Offsetting\t and\t Reduction\t Scheme\t for\t International\t Aviation\t (CORSIA),\t an',
#  'international,\tmarket-based\temissions\treduction\tprogram\tadopted\tby\tthe\tInternational\tCivil\tAviation\tOrganization\t(ICAO)\tin\t2016.\tCORSIA\tis\tintended\tto',
#  'achieve\tcarbon-neutral\tgrowth\t in\t the\t international\taviation\tsector\t from\t2021\tthrough\t2035\tby\trequiring\tairlines\t to\tcompensate\t for\t the\tgrowth\t in\tcarbon',
#  'dioxide\t(CO )\temissions,\trelative\tto\ta\tpredetermined\tbaseline,\tof\ta\tsignificant\tmajority\tof\tinternational\tflights\tthrough\tthe\tpurchase\tof\tcarbon\toffsets\tor\tthe',
#  'use\tof\tlow-carbon\tfuels.\tFor\teach\tyear\tfrom\t2021\tthrough\t2029,\tCORSIA\trequires\teach\tairline\tto\tcompensate\tfor\tthe\trate\tof\tgrowth\tof\tthe\tCO \temissions',
#  'of\tthe\taviation\tsector\tas\ta\twhole\tas\tdetermined\tby\tICAO.\tStarting\tin\t2030,\tCORSIA\twill\trequire\tairlines\tto\tcompensate\tfor\tgrowth\tin\tCO \temissions\tusing',
#  'a\t formula\tdetermined\tby\t ICAO\t that\twill\t combine\t the\tgrowth\t in\t aviation\t sector\t emissions\tand\t the\tgrowth\t in\t the\t individual\t airline’s\t emissions,\twith\t the',
#  ...]

# %%
result = [x for x in rawList if x[:4] == 'ITEM']

# %%
result
# Out:
# ['ITEM\t1.\tBUSINESS',
#  'ITEM\t1A.\tRISK\tFACTORS',
#  'ITEM\t1B.\tUNRESOLVED\tSTAFF\tCOMMENTS',
#  'ITEM\t2.\tPROPERTIES',
#  'ITEM\t3.\t\tLEGAL\tPROCEEDINGS',
#  'ITEM\t4.\t\tMINE\tSAFETY\tDISCLOSURES',
#  'ITEM\t5.\t\t\t\tMARKET\tFOR\tAMERICAN\tAIRLINES\tGROUP’S\tCOMMON\tSTOCK,\tRELATED\tSTOCKHOLDER\tMATTERS\tAND\tISSUER\tPURCHASES',
#  'ITEM\t6.\t\tSELECTED\tCONSOLIDATED\tFINANCIAL\tDATA',
#  'ITEM\t7.\t\tMANAGEMENT’S\tDISCUSSION\tAND\tANALYSIS\tOF\tFINANCIAL\tCONDITION\tAND\tRESULTS\tOF\tOPERATIONS',
#  'ITEM\t7A.\tQUANTITATIVE\tAND\tQUALITATIVE\tDISCLOSURES\tABOUT\tMARKET\tRISK',
#  'ITEM\t8A.\tCONSOLIDATED\tFINANCIAL\tSTATEMENTS\tAND\tSUPPLEMENTARY\tDATA\tOF\tAMERICAN\tAIRLINES\tGROUP\tINC.',
#  'ITEM\t8B.\tCONSOLIDATED\tFINANCIAL\tSTATEMENTS\tAND\tSUPPLEMENTARY\tDATA\tOF\tAMERICAN\tAIRLINES,\tINC.',
#  'ITEM\t9.\t\tCHANGES\tIN\tAND\tDISAGREEMENTS\tWITH\tACCOUNTANTS\tON\tACCOUNTING\tAND\tFINANCIAL\tDISCLOSURE',
#  'ITEM\t9A.\t\tCONTROLS\tAND\tPROCEDURES',
#  'ITEM\t9B.\t\tOTHER\tINFORMATION',
#  'ITEM\t10.\t\tDIRECTORS,\tEXECUTIVE\tOFFICERS\tAND\tCORPORATE\tGOVERNANCE',
#  'ITEM\t11.\t\tEXECUTIVE\tCOMPENSATION',
#  'ITEM\t12.\t\tSECURITY\tOWNERSHIP\tOF\tCERTAIN\tBENEFICIAL\tOWNERS\tAND\tMANAGEMENT\tAND\tRELATED\tSTOCKHOLDER\tMATTERS',
#  'ITEM\t13.\t\tCERTAIN\tRELATIONSHIPS\tAND\tRELATED\tTRANSACTIONS,\tAND\tDIRECTOR\tINDEPENDENCE',
#  'ITEM\t14.\t\tPRINCIPAL\tACCOUNTANT\tFEES\tAND\tSERVICES',
#  'ITEM\t15.\t\tEXHIBITS\tAND\tFINANCIAL\tSTATEMENT\tSCHEDULES',
#  'ITEM\t16.\t\tFORM\t10-K\tSUMMARY']

# %% [markdown]
# I wonder if this strategy will work for all forms? This would be very handy... Let's see if we can extract the necessary information:

# %%
matches = re.compile(r'^ITEM.*7[^A][^A]')
item7 = [matches.search(x) for x in result]

#rawList.index([-1])
[x for x in rawList if matches.search(x) != None]
# Out:
# ["ITEM\t7. MANAGEMENT'S\tDISCUSSION\tAND\tANALYSIS\tOF\tFINANCIAL\tCONDITION\tAND\tRESULTS\tOF\tOPERATIONS"]

# %%
idx7 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

# %%
matches = re.compile(r'^ITEM.*8[^B][^B]')
item7 = [matches.search(x) for x in result]
[x for x in rawList if matches.search(x) != None]
# Out:
# ['ITEM\t8A. AAG\tCONSOLIDATED\tFINANCIAL\tSTATEMENTS']

# %%
idx8 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

# %%
print(''.join(rawList[idx7:idx8]))
# Out:
# ITEM	7. MANAGEMENT'S	DISCUSSION	AND	ANALYSIS	OF	FINANCIAL	CONDITION	AND	RESULTS	OF	OPERATIONSAmerican	Airlines	GroupBackgroundAs	 previously	 discussed,	 the	 Merger	 was	 consummated	 on	 December	 9,	 2013.	Accordingly,	 the	 Company’s	 consolidated	 results	 include	American	 andAmerican	Eagle	for	the	year	ended	December	31,	2013	and	the	results	of	US	Airways	Group	for	the	23	days	ended	December	31,	2013.Following	the	Merger,	AAG	began	moving	toward	operating	under	the	single	brand	name	of	"American	Airlines"	through	its	mainline	operations,	Americanand	US	Airways.	Until	a	single	operating	certificate	is	issued	by	the	Federal	Aviation	Administration	(FAA)	and	the	operational	integration	is	complete,	American	andUS	Airways	will	continue	 to	operate	as	 separate	airlines.	This	process	 is	expected	 to	 take	18-24	months.	Through	 its	operating	subsidiaries,	 including	 the	operatingsubsidiaries	of	US	Airways	Group,	AAG	 is	 the	 largest	 airline	 in	 the	world	 as	measured	by	 revenue	passenger	miles	 (RPMs)	 and	available	 seat	miles	 (ASMs).	TheCompany	 has	 primary	 hubs	 in	 Charlotte,	 Chicago,	 Dallas/Fort	Worth,	 Los	Angeles,	 Miami,	 New	York	 City,	 Philadelphia,	 Phoenix	 and	Washington,	 D.C.	As	 ofDecember	31,	2013,	the	combined	airline	operated	nearly	6,700	daily	flights	to	339	destinations	in	54	countries.	As	of	December	31,	2013,	American	and	US	Airwaysoperated	965	mainline	jets.	American	continues	to	be	provided	with	regional	feed	by	American	Eagle	and	third-party	regional	carriers	and	US	Airways	continues	to	beprovided	with	 regional	 feed	by	Piedmont,	PSA	and	 third-party	 regional	 carriers.	As	of	December	31,	2013,	 the	Company’s	 regional	 subsidiaries	 and	 the	 third-partyregional	carriers	that	provide	it	with	regional	feed	operated	approximately	519	regional	jets	and	approximately	40	turboprops.See	Part	I,	Item	1.	Business	-	"Chapter	11	Reorganization"	and	"Merger"	for	more	information	related	to	our	emergence	from	Chapter	11	and	Merger.Year	in	ReviewThe	U.S.	Airline	IndustryIn	2013,	the	U.S.	airline	industry	experienced	year-over-year	growth	in	passenger	revenues	driven	by	strong	demand	for	air	travel.In	its	most	recent	data	available,	Airlines	for	America,	the	trade	association	for	U.S.	airlines,	reported	that	annual	U.S.	industry	passenger	revenues	and	yieldsincreased	3.8%	and	2.0%,	respectively,	as	compared	to	2012.	With	respect	to	international	versus	domestic	performance,	Airlines	for	America	reported	that	the	Atlanticand	Latin	America	markets	outperformed	domestic	markets	in	year-over-year	growth	in	passenger	revenues	while	the	Pacific	market	experienced	year-over-year	declinesin	passenger	revenues.Throughout	2013,	jet	fuel	prices	continued	to	follow	the	price	of	Brent	crude	oil	more	closely	than	the	price	of	West	Texas	Intermediate	crude	oil.	On	average,fuel	costs	were	down	slightly	in	2013	as	compared	to	2012.	The	Brent	crude	oil	average	daily	spot	price	was	$109	in	2013	which	approximates	the	average	daily	spotprice	in	2012.	However,	on	a	daily	basis,	prices	continued	to	be	volatile.	Throughout	2013,	daily	spot	prices	fluctuated	between	a	high	of	$119	per	barrel	in	February	to	alow	of	$97	per	barrel	in	April	and	closed	the	year	at	$110	per	barrel	on	December	31,	2013.While	the	U.S.	airline	industry	is	currently	benefiting	from	a	favorable	revenue	environment	and	moderating	fuel	prices	as	described	above,	uncertainty	existsregarding	the	economic	conditions	driving	these	factors.	See	Part	I,	Item	1A.	Risk	Factors	-	"Downturns	in	economic	conditions	adversely	affect	our	business"	and	"Ourbusiness	is	dependent	on	the	price	and	availability	of	aircraft	fuel.	Continued	periods	of	high	volatility	in	fuel	costs,	increased	fuel	prices	and	significant	disruptions	inthe	supply	of	aircraft	fuel	could	have	a	significant	negative	impact	on	our	operating	results	and	liquidity."American	Airlines	GroupIn	2013,	we	realized	operating	income	of	$1.4	billion	and	a	net	loss	of	$1.8	billion.	We	completed	our	merger ...

# %%
link_dict['0000006201']
# Out:
#           accessionNumber  filingDate  reportDate        acceptanceDateTime  \
# 49   0000006201-21-000014  2021-02-17  2020-12-31  2021-02-17T17:17:57.000Z
# 150  0000006201-20-000023  2020-02-19  2019-12-31  2020-02-19T07:31:30.000Z
# 225  0000006201-19-000009  2019-02-25  2018-12-31  2019-02-25T07:31:34.000Z
# 315  0000006201-18-000009  2018-02-21  2017-12-31  2018-02-21T08:02:40.000Z
# 412  0001193125-17-051216  2017-02-22  2016-12-31  2017-02-22T08:01:43.000Z
# 538  0001193125-16-474605  2016-02-24  2015-12-31  2016-02-24T08:04:10.000Z
# 651  0001193125-15-061145  2015-02-25  2014-12-31  2015-02-25T08:02:34.000Z
# 750  0000006201-14-000004  2014-02-28  2013-12-31  2014-02-28T07:52:16.000Z
#
#     act  form fileNumber filmNumber items      size  isXBRL  isInlineXBRL  \
# 49   34  10-K  001-08400   21646186        43925703       1             1
# 150  34  10-K  001-08400   20627428        30851334       1             1
# 225  34  10-K  001-08400   19628071        30572408       1             0
# 315  34  10-K  001-08400   18627088        27914491       1             0
# 412  34  10-K  001-08400   17627073        24888480       1             0
# 538  34  10-K  001-08400  161450518        26170400       1             0
# 651  34  10-K  001-08400   15645918        39524925       1             0
# 750  34  10-K  001-08400   14651496        47888955       1             0
#
#            primaryDocument primaryDocDescription  \
# 49        aal-20201231.htm    10-K 2020 02.17.21
# 150         a10k123119.htm    10-K 2019 02.19.20
# 225         a10k123118.htm    10-K 2018 02.25.19
# 315         a10k123117.htm                  10-K
# 412        d286458d10k.htm             FORM 10-K
# 538         d78287d10k.htm             FORM 10-K
# 651        d829913d10k.htm             FORM 10-K
# 750  aagaa10k-20131231.htm                  10-K
#
#                                                   Link  \
# 49   https://www.sec.gov/Archives/edgar/data/6201/0...
# 150  https://www.sec.gov/Archives/edgar/data/6201/0...
# 225  https://www.sec.gov/Archives/edgar/data/6201/0...
# 315  https://www.sec.gov/Archives/edgar/data/6201/0...
# 412  https://www.sec.gov/Archives/edgar/data/6201/0...
# 538  https://www.sec.gov/Archives/edgar/data/6201/0...
# 651  https://www.sec.gov/Archives/edgar/data/6201/0...
# 750  https://www.sec.gov/Archives/edgar/data/6201/0...
#
#                                                   Loc7  \
# 49   [[(158292, 158310), Item 7. Management], [(167...
# 150  [[(153128, 153146), Item 7. Management], [(156...
# 225  [[(9505, 9523), Item 7. Management], [(12796, ...
# 315  [[(9554, 9572), Item 7. Management], [(13606, ...
# 412  [[(9935, 9953), Item 7. Management], [(14047, ...
# 538  [[(17027, 17045), Item 7. Management], [(21453...
# 651  [[(16174, 16192), Item 7. Management], [(23008...
# 750  [[(15590, 15608), Item 7. Management], [(23363...
#
#                                             Loc8
# 49   [[(502641, 502662), ITEM 8A. CONSOLIDATED]]
# 150  [[(414897, 414918), ITEM 8A. CONSOLIDATED]]
# 225  [[(300867, 300888), ITEM 8A. CONSOLIDATED]]
# 315  [[(293380, 293401), ITEM 8A. CONSOLIDATED]]
# 412  [[(297249, 297270), ITEM 8A. CONSOLIDATED]]
# 538  [[(398001, 398022), ITEM 8A. CONSOLIDATED]]
# 651  [[(452689, 452710), ITEM 8A. CONSOLIDATED]]
# 750                                           []

# %%
for link in link_dict['0000006201']['Link'].values:
    pdfkit.from_url(link, 'out.pdf')
    rawText = parser.from_file('out.pdf')
    rawList = rawText['content'].splitlines()
    result = [x for x in rawList if x[:4] == 'ITEM']
    print(len(result))
# Out:
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 22
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 22
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 21
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 21
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 21
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 20
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 20
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 21

# %%
response = json.loads(requests.get("https://data.sec.gov/submissions/CIK"+cik+".json", headers=heads).text)
