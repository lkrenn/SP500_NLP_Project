# %% [markdown]
# # Layout Parser Tutorial
#
# In this notebook, we will be implementing a Python package called LayoutParser. We will be taking an image-recognition approach to see if perhaps we can do document segmentation that way.

# %%
# Need this for Tesseract to function properly
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# Delete unused packages once idea is fully realized
import numpy as np
import pdfkit
#import fpdf
import pandas as pd
import os
import pickle
import time
import json
import requests
import re
import urllib
from bs4 import BeautifulSoup

from pdf2image import convert_from_path, convert_from_bytes
from pytesseract import pytesseract
import layoutparser as lp
import matplotlib.pyplot as plt
import cv2 

from datetime import datetime

#import pytesseract
from PIL import ImageEnhance, ImageFilter, Image

import lxml.html

# %% [markdown]
# First, let's see if we can convert our documents to a picture right away. This may make the process significantly easier.

# %%
with open('../Step1-Data/2-link_dict.pickle', 'rb') as f:
    link_dict = pickle.load(f)

# %%
sample = link_dict['0000006201'].copy()
sample_link = sample['Link'].values[0]

# %%
pdfkit.from_url(sample_link, 'out.pdf')
# Out:
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# True

# %%
from tika import parser

rawText = parser.from_file('Out.pdf')

rawList = rawText['content'].splitlines()

# %%
rawList[200:220]
# Out:
# ['General',
#  'This\treport\tis\tfiled\tby\tAmerican\tAirlines\tGroup\tInc.\t(AAG)\tand\tits\twholly-owned\tsubsidiary\tAmerican\tAirlines,\tInc.\t(American).\tReferences\tin\tthis\tAnnual',
#  '',
#  'Report\ton\tForm\t10-K\tto\t“we,”\t“us,”\t“our,”\tthe\t“Company”\tand\tsimilar\tterms\trefer\tto\tAAG\tand\tits\tconsolidated\tsubsidiaries.\t“AMR”\tor\t“AMR\tCorporation”',
#  'refers\tto\tthe\tCompany\tduring\tthe\tperiod\tof\ttime\tprior\tto\tits\temergence\tfrom\tChapter\t11\tand\tits\tacquisition\tof\tUS\tAirways\tGroup,\tInc.\t(US\tAirways\tGroup)',
#  'on\tDecember\t9,\t2013\t(the\tMerger).\tReferences\tto\tUS\tAirways\tGroup\tand\tUS\tAirways,\tInc.,\ta\tsubsidiary\tof\tUS\tAirways\tGroup\t(US\tAirways),\trepresent',
#  'the\tentities\tduring\tthe\tperiod\tof\ttime\tprior\tto\tthe\tdissolution\tof\tthose\tentities\tin\tconnection\twith\tAAG’s\tinternal\tcorporate\trestructuring\ton\tDecember\t30,',
#  '2015.\tReferences\tin\tthis\treport\tto\t“mainline”\trefer\tto\tthe\toperations\tof\tAmerican\tonly\tand\texclude\tregional\toperations.',
#  '',
#  'Glossary\tof\tTerms',
#  'For\t the\t convenience\t of\t the\t reader,\t the\t definitions\t of\t certain\t industry\t and\t other\t terms\t used\t in\t this\t report\t have\t been\t consolidated\t into\t a\t glossary',
#  '',
#  'beginning\ton\tpage\t20.',
#  '',
#  'Note\tConcerning\tForward-Looking\tStatements',
#  'Certain\tof\tthe\tstatements\tcontained\tin\tthis\treport\tshould\tbe\tconsidered\tforward-looking\tstatements\twithin\tthe\tmeaning\tof\tthe\tSecurities\tAct\tof\t1933,\tas',
#  '',
#  'amended\t(the\tSecurities\tAct),\tthe\tSecurities\tExchange\tAct\tof\t1934,\tas\tamended\t(the\tExchange\tAct),\tand\tthe\tPrivate\tSecurities\tLitigation\tReform\tAct\tof',
#  '1995.\tThese\t forward-looking\t statements\tmay\t be\t identified\t by\twords\t such\t as\t “may,”\t “will,”\t “expect,”\t “intend,”\t “anticipate,”\t “believe,”\t “estimate,”\t “plan,”',
#  '“project,”\t“could,”\t“should,”\t“would,”\t“continue,”\t“seek,”\t“target,”\t“guidance,”\t“outlook,”\t“if\tcurrent\ttrends\tcontinue,”\t“optimistic,”\t“forecast”\tand\tother\tsimilar']

# %%
result = [x for x in rawList if x[:4] == 'ITEM']

# %%
result
# Out:
# ['ITEM\t1.\tBUSINESS',
#  'ITEM\t1A.\tRISK\tFACTORS',
#  'ITEM\t1B.\tUNRESOLVED\tSTAFF\tCOMMENTS',
#  'ITEM\t2.\tPROPERTIES',
#  'ITEM\t3.\t\tLEGAL\tPROCEEDINGS',
#  'ITEM\t4.\t\tMINE\tSAFETY\tDISCLOSURES',
#  'ITEM\t5.\t\t\t\tMARKET\tFOR\tAMERICAN\tAIRLINES\tGROUP’S\tCOMMON\tSTOCK,\tRELATED\tSTOCKHOLDER\tMATTERS\tAND\tISSUER\tPURCHASES',
#  'ITEM\t6.\t\tSELECTED\tCONSOLIDATED\tFINANCIAL\tDATA',
#  'ITEM\t7.\t\tMANAGEMENT’S\tDISCUSSION\tAND\tANALYSIS\tOF\tFINANCIAL\tCONDITION\tAND\tRESULTS\tOF\tOPERATIONS',
#  'ITEM\t7A.\tQUANTITATIVE\tAND\tQUALITATIVE\tDISCLOSURES\tABOUT\tMARKET\tRISK',
#  'ITEM\t8A.\tCONSOLIDATED\tFINANCIAL\tSTATEMENTS\tAND\tSUPPLEMENTARY\tDATA\tOF\tAMERICAN\tAIRLINES\tGROUP\tINC.',
#  'ITEM\t8B.\tCONSOLIDATED\tFINANCIAL\tSTATEMENTS\tAND\tSUPPLEMENTARY\tDATA\tOF\tAMERICAN\tAIRLINES,\tINC.',
#  'ITEM\t9.\t\tCHANGES\tIN\tAND\tDISAGREEMENTS\tWITH\tACCOUNTANTS\tON\tACCOUNTING\tAND\tFINANCIAL\tDISCLOSURE',
#  'ITEM\t9A.\t\tCONTROLS\tAND\tPROCEDURES',
#  'ITEM\t9B.\t\tOTHER\tINFORMATION',
#  'ITEM\t10.\t\tDIRECTORS,\tEXECUTIVE\tOFFICERS\tAND\tCORPORATE\tGOVERNANCE',
#  'ITEM\t11.\t\tEXECUTIVE\tCOMPENSATION',
#  'ITEM\t12.\t\tSECURITY\tOWNERSHIP\tOF\tCERTAIN\tBENEFICIAL\tOWNERS\tAND\tMANAGEMENT\tAND\tRELATED\tSTOCKHOLDER\tMATTERS',
#  'ITEM\t13.\t\tCERTAIN\tRELATIONSHIPS\tAND\tRELATED\tTRANSACTIONS,\tAND\tDIRECTOR\tINDEPENDENCE',
#  'ITEM\t14.\t\tPRINCIPAL\tACCOUNTANT\tFEES\tAND\tSERVICES',
#  'ITEM\t15.\t\tEXHIBITS\tAND\tFINANCIAL\tSTATEMENT\tSCHEDULES',
#  'ITEM\t16.\t\tFORM\t10-K\tSUMMARY']

# %% [markdown]
# I wonder if this strategy will work for all forms? This would be very handy... Let's see if we can extract the necessary information:

# %%
matches = re.compile(r'^ITEM.*1[^A][^A].*BUSINESS')
item7 = [matches.search(x) for x in result]

#rawList.index([-1])
[x for x in rawList if matches.search(x) != None]
# Out:
# ['ITEM\t1.\tBUSINESS']

# %%
idx7 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

# %%
matches = re.compile(r'^ITEM.*8[^B][^B]')
item7 = [matches.search(x) for x in result]
[x for x in rawList if matches.search(x) != None]
# Out:
# ['ITEM\t8A.\tCONSOLIDATED\tFINANCIAL\tSTATEMENTS\tAND\tSUPPLEMENTARY\tDATA\tOF\tAMERICAN\tAIRLINES\tGROUP\tINC.']

# %%
idx8 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

# %%
item7str = ' '.join(rawList[idx7:idx8]).replace('\t', ' ')
#item7str

# %% [markdown]
# # Expand to All Filings For One Company

# %%
options = { 'quiet': '' }
start = time.time()
item7_company = []
for link in link_dict['0000006201']['Link'].values:
    pdfkit.from_url(link, 'out.pdf', options=options)
    rawText = parser.from_file('out.pdf')
    rawList = rawText['content'].splitlines()
    result = [x for x in rawList if x[:4] == 'ITEM']
    
    try:
        ##### ITEM 7
        matches = re.compile(r'^ITEM.*7[^A][^A]')
        item7 = [matches.search(x) for x in result]
        idx7 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

        ##### ITEM 8
        matches = re.compile(r'^ITEM.*8[^B][^B]')
        item7 = [matches.search(x) for x in result]
        idx8 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

        item7_company.append(' '.join(rawList[idx7:idx8]).replace('\t', ' '))
    except:
        item7_company.append('')
    
end = time.time()

# %%
print(end-start)
# Out:
# 70.30988907814026

# %%
link_dict['0000006201']['Item7'] = item7_company

# %%
link_dict['0000006201']
# Out:
#           accessionNumber  filingDate  reportDate        acceptanceDateTime  \
# 49   0000006201-21-000014  2021-02-17  2020-12-31  2021-02-17T17:17:57.000Z
# 150  0000006201-20-000023  2020-02-19  2019-12-31  2020-02-19T07:31:30.000Z
# 225  0000006201-19-000009  2019-02-25  2018-12-31  2019-02-25T07:31:34.000Z
# 315  0000006201-18-000009  2018-02-21  2017-12-31  2018-02-21T08:02:40.000Z
# 412  0001193125-17-051216  2017-02-22  2016-12-31  2017-02-22T08:01:43.000Z
# 538  0001193125-16-474605  2016-02-24  2015-12-31  2016-02-24T08:04:10.000Z
# 651  0001193125-15-061145  2015-02-25  2014-12-31  2015-02-25T08:02:34.000Z
# 750  0000006201-14-000004  2014-02-28  2013-12-31  2014-02-28T07:52:16.000Z
#
#     act  form fileNumber filmNumber items      size  isXBRL  isInlineXBRL  \
# 49   34  10-K  001-08400   21646186        43925703       1             1
# 150  34  10-K  001-08400   20627428        30851334       1             1
# 225  34  10-K  001-08400   19628071        30572408       1             0
# 315  34  10-K  001-08400   18627088        27914491       1             0
# 412  34  10-K  001-08400   17627073        24888480       1             0
# 538  34  10-K  001-08400  161450518        26170400       1             0
# 651  34  10-K  001-08400   15645918        39524925       1             0
# 750  34  10-K  001-08400   14651496        47888955       1             0
#
#            primaryDocument primaryDocDescription  \
# 49        aal-20201231.htm    10-K 2020 02.17.21
# 150         a10k123119.htm    10-K 2019 02.19.20
# 225         a10k123118.htm    10-K 2018 02.25.19
# 315         a10k123117.htm                  10-K
# 412        d286458d10k.htm             FORM 10-K
# 538         d78287d10k.htm             FORM 10-K
# 651        d829913d10k.htm             FORM 10-K
# 750  aagaa10k-20131231.htm                  10-K
#
#                                                   Link  \
# 49   https://www.sec.gov/Archives/edgar/data/6201/0...
# 150  https://www.sec.gov/Archives/edgar/data/6201/0...
# 225  https://www.sec.gov/Archives/edgar/data/6201/0...
# 315  https://www.sec.gov/Archives/edgar/data/6201/0...
# 412  https://www.sec.gov/Archives/edgar/data/6201/0...
# 538  https://www.sec.gov/Archives/edgar/data/6201/0...
# 651  https://www.sec.gov/Archives/edgar/data/6201/0...
# 750  https://www.sec.gov/Archives/edgar/data/6201/0...
#
#                                                   Loc7  \
# 49   [[(158292, 158310), Item 7. Management], [(167...
# 150  [[(153128, 153146), Item 7. Management], [(156...
# 225  [[(9505, 9523), Item 7. Management], [(12796, ...
# 315  [[(9554, 9572), Item 7. Management], [(13606, ...
# 412  [[(9935, 9953), Item 7. Management], [(14047, ...
# 538  [[(17027, 17045), Item 7. Management], [(21453...
# 651  [[(16174, 16192), Item 7. Management], [(23008...
# 750  [[(15590, 15608), Item 7. Management], [(23363...
#
#                                             Loc8
# 49   [[(502641, 502662), ITEM 8A. CONSOLIDATED]]
# 150  [[(414897, 414918), ITEM 8A. CONSOLIDATED]]
# 225  [[(300867, 300888), ITEM 8A. CONSOLIDATED]]
# 315  [[(293380, 293401), ITEM 8A. CONSOLIDATED]]
# 412  [[(297249, 297270), ITEM 8A. CONSOLIDATED]]
# 538  [[(398001, 398022), ITEM 8A. CONSOLIDATED]]
# 651  [[(452689, 452710), ITEM 8A. CONSOLIDATED]]
# 750                                           []

# %%
with open('../Step1-Data/8-link_dict.pickle', 'rb') as f:
    link_dict = pickle.load(f)

# %% [markdown]
# # Extend to All Companies

# %%
options = { 'quiet': '' }

counter = 0
for company in list(link_dict.keys()):
    
    now = datetime.now()
    print(counter, ' - ', now.strftime("%H:%M:%S"))
    item1_company = []
    item1a_company = []
    item7_company = []
    for link in link_dict[company]['Link'].values:
        try:
            pdfkit.from_url(link, 'out.pdf', options=options)
            
        except:
            item1_company.append('')
            item1a_company.append('')
            item7_company.append('')
            continue
            
        rawText = parser.from_file('out.pdf')
        rawList = rawText['content'].splitlines()
        result = [x for x in rawList if re.match('ITEM', x[:4], re.IGNORECASE)]
        
        try:
            ##### ITEM 1
            matches = re.compile(r'^ITEM.*1[^A].*BUSINESS', re.IGNORECASE)
            #item7 = [matches.search(x) for x in result]
            idx1 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

            ##### ITEM 1A
            matches = re.compile(r'^ITEM.*1(A| A)', re.IGNORECASE)
            #item7 = [matches.search(x) for x in result]
            idx1a = rawList.index([x for x in rawList if matches.search(x) != None][-1])
            
            item1_company.append(' '.join(rawList[idx1:idx1a]).replace('\t', ' '))
        
        except:
            item1_company.append('')
        
        try:
            ##### ITEM 1A
            matches = re.compile(r'^ITEM.*1(A| A)', re.IGNORECASE)
            #item7 = [matches.search(x) for x in result]
            idx1a = rawList.index([x for x in rawList if matches.search(x) != None][-1])

            ##### ITEM 1B
            matches = re.compile(r'^ITEM.*1(B| B)', re.IGNORECASE)
            #item7 = [matches.search(x) for x in result]
            idx1b = rawList.index([x for x in rawList if matches.search(x) != None][-1])
            
            item1a_company.append(' '.join(rawList[idx1a:idx1b]).replace('\t', ' '))
        
        except:
            item1a_company.append('')

        try:
            
            ##### ITEM 7
            matches = re.compile(r'^ITEM.*7[^A][^A]', re.IGNORECASE)
            #item7 = [matches.search(x) for x in result]
            idx7 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

            ##### ITEM 8
            matches = re.compile(r'^ITEM.*8[^B][^B]', re.IGNORECASE)
            #item7 = [matches.search(x) for x in result]
            idx8 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

            item7_company.append(' '.join(rawList[idx7:idx8]).replace('\t', ' '))
        except:
            item7_company.append('')
    
    link_dict[company]['Item1']  = item1_company
    link_dict[company]['Item1a'] = item1a_company
    link_dict[company]['Item7']  = item7_company
    
    if counter % 50 == 0:
        with open('8-link_dict.pickle', 'wb') as handle:
            pickle.dump(link_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
    counter += 1
    
with open('8-link_dict.pickle', 'wb') as handle:
            pickle.dump(link_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# 0  -  23:14:08
# 1  -  23:15:22
# 2  -  23:15:58
# 3  -  23:16:36
# 4  -  23:17:17
# 5  -  23:17:54
# 6  -  23:18:19
# 7  -  23:20:21
# 8  -  23:21:08
# 9  -  23:21:38
# 10  -  23:22:06
# 11  -  23:23:16
# 12  -  23:23:48
# 13  -  23:24:05
# 14  -  23:24:38
# 15  -  23:24:54
# 16  -  23:25:45
# 17  -  23:26:24
# 18  -  23:26:54
# 19  -  23:27:36
# 20  -  23:28:21
# 21  -  23:29:20
# 22  -  23:30:13
# 23  -  23:30:29
# 24  -  23:32:38
# 25  -  23:33:32
# 26  -  23:36:11
# 27  -  23:36:36
# 28  -  23:38:57
# 29  -  23:38:57
# 30  -  23:39:25
# 31  -  23:40:53
# 32  -  23:41:26
# 33  -  23:42:36
# 34  -  23:43:48
# 35  -  23:44:40
# 36  -  23:45:16
# 37  -  23:46:03
# 38  -  23:46:50
# 39  -  23:47:57
# 40  -  23:48:49
# 41  -  23:49:38
# 42  -  23:51:38
# 43  -  23:52:42
# 44  -  23:53:24
# 45  -  23:54:18
# 46  -  23:55:07
# 47  -  23:56:05
# 48  -  23:56:59
# 49  -  23:57:46
# 50  -  23:58:21
# 51  -  23:59:19
# 52  -  00:00:10
# 53  -  00:01:14
# 54  -  00:02:25
# 55  -  00:03:23
# 56  -  00:03:55
# 52   [[(92292, 92310), Item 7. Management], [(10599...
# 179  [[(89201, 89219), Item 7. Management], [(99210...
# 278             [[(66526, 66544), Item 7. Management]]
# 387             [[(64008, 64026), Item 7. Management]]
# 497             [[(84532, 84550), Item 7. Management]]
# 631                                                 []
# 751                                                 []
# 879                                                 []
#
#                                         Loc8  \
# 52   [[(135183, 135200), Item 8. Financial]]
# 179  [[(122041, 122058), Item 8. Financial]]
# 278  [[(103131, 103148), Item 8. Financial]]
# 387  [[(103875, 103892), Item 8. Financial]]
# 497  [[(152790, 152807), Item 8. Financial]]
# 631  [[(159224, 159241), Item 8. Financial]]
# 751  [[(158395, 158412), Item 8. Financial]]
# 879  [[(155007, 155024), Item 8. Financial]]
#
#                                                  Item7
# 52   Item 7. Management’s Discussion and Analysis o...
# 179  Item 7. Management’s Discussion and Analysis o...
# 278  Item 7. Management’s Discussion and Analysis o...
# 387  Item 7. Management’s Discussion and Analysis o...
# 497  Item 7. Management’s Discussion and Analysis o...
# 631  Item 7. Management’s Discussion and Analysis o...
# 751  Item 7. Management’s Discussion and Analysis o...
# 879  Item 7. Management’s Discussion and Analysis o...

# %%
with open('6-link_dict.pickle', 'wb') as handle:
    pickle.dump(link_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
list(link_dict.keys()).index(company)
# Out:
# 765

# %%
https://www.sec.gov/Archives/edgar/data/835910/000083591001000012/0000835910-01-000012.txt

# %%
for link in link_dict['0000006201']['Link'].values:
    pdfkit.from_url(link, 'out.pdf')
    rawText = parser.from_file('out.pdf')
    rawList = rawText['content'].splitlines()
    result = [x for x in rawList if x[:4] == 'ITEM']
    print(len(result))
# Out:
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 22
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 22
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 21
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 21
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 21
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 20
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 20
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 21

# %%
response = json.loads(requests.get("https://data.sec.gov/submissions/CIK"+cik+".json", headers=heads).text)

# %%
badslist = []
for company in companies:
    bads = [len(x) for x in link_dict[company]['Item7'].values]
    if bads.count(0) > 0:
        badslist.append(company)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-04d72458ec9a> in <module>
#       1 badslist = []
# ----> 2 for company in companies:
#       3     bads = [len(x) for x in link_dict[company]['Item7'].values]
#       4     if bads.count(0) > 0:
#       5         badslist.append(company)
#
# NameError: name 'companies' is not defined

# %%
goodslist = [x for x in link_dict.keys() if x not in badslist]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-22cf194874fd> in <module>
# ----> 1 goodslist = [x for x in link_dict.keys() if x not in badslist]
#
# <ipython-input-8-22cf194874fd> in <listcomp>(.0)
# ----> 1 goodslist = [x for x in link_dict.keys() if x not in badslist]
#
# NameError: name 'badslist' is not defined

# %%
company = '0001158449'

# %%
now = datetime.now()
print(counter, ' - ', now.strftime("%H:%M:%S"))
item1_company = []
item1a_company = []
item7_company = []
for link in link_dict[company]['Link'].values:
    try:
        pdfkit.from_url(link, 'out.pdf', options=options)

    except:
        item1_company.append('')
        item1a_company.append('')
        item7_company.append('')
        continue

    rawText = parser.from_file('out.pdf')
    rawList = rawText['content'].splitlines()
    result = [x for x in rawList if re.match('ITEM', x[:4], re.IGNORECASE)]

    try:
        ##### ITEM 1
        matches = re.compile(r'^ITEM.*1[^A][^A].*BUSINESS', re.IGNORECASE)
        #item7 = [matches.search(x) for x in result]
        idx1 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

        ##### ITEM 1A
        matches = re.compile(r'^ITEM.*1(A| A)', re.IGNORECASE)
        #item7 = [matches.search(x) for x in result]
        idx1a = rawList.index([x for x in rawList if matches.search(x) != None][-1])

        item1_company.append(' '.join(rawList[idx1:idx1a]).replace('\t', ' '))

    except:
        item1_company.append('')

    try:
        ##### ITEM 1A
        matches = re.compile(r'^ITEM.*1(A| A)', re.IGNORECASE)
        #item7 = [matches.search(x) for x in result]
        idx1a = rawList.index([x for x in rawList if matches.search(x) != None][-1])

        ##### ITEM 1B
        matches = re.compile(r'^ITEM.*1(B| B)', re.IGNORECASE)
        #item7 = [matches.search(x) for x in result]
        idx1b = rawList.index([x for x in rawList if matches.search(x) != None][-1])

        item1a_company.append(' '.join(rawList[idx1a:idx1b]).replace('\t', ' '))

    except:
        item1a_company.append('')

    try:

        ##### ITEM 7
        matches = re.compile(r'^ITEM.*7[^A][^A]', re.IGNORECASE)
        #item7 = [matches.search(x) for x in result]
        idx7 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

        ##### ITEM 8
        matches = re.compile(r'^ITEM.*8[^B][^B]', re.IGNORECASE)
        #item7 = [matches.search(x) for x in result]
        idx8 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

        item7_company.append(' '.join(rawList[idx7:idx8]).replace('\t', ' '))
    except:
        item7_company.append('')

link_dict[company]['Item1']  = item1_company
link_dict[company]['Item1a'] = item1a_company
link_dict[company]['Item7']  = item7_company
# Out:
# 23  -  20:51:26
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-1b035357ecf9> in <module>
#      66         item7_company.append('')
#      67
# ---> 68 link_dict[company]['Item1']  = item1_company
#      69 link_dict[company]['Item1a'] = item1a_company
#      70 link_dict[company]['Item7']  = item7_company
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# -> 3899             value = sanitize_index(value, self.index)
#    3900             if not isinstance(value, (np.ndarray, Index)):
#    3901                 if isinstance(value, list) and len(value) > 0:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     750     if len(data) != len(index):
#     751         raise ValueError(
# --> 752             "Length of values "
#     753             f"({len(data)}) "
#     754             "does not match length of index "
#
# ValueError: Length of values (1) does not match length of index (8)

# %% [markdown]
# result

# %%
result
# Out:
# ['Item\t1.\t\t\t\tBusiness.',
#  'Item\t1A.\tRisk\tFactors.',
#  'Item\t1B.\tUnresolved\tStaff\tComments.',
#  'Item\t2.\tProperties.',
#  'Item\t3.\tLegal\tProceedings.',
#  'Item\t4.\tMine\tSafety\tDisclosures.',
#  'Item\t5. Market\t for\t Registrant’s\t Common\t Equity,\t Related\t Stockholder\t Matters\t and\t Issuer\t Purchases\t of\t Equity',
#  'Item\t6.\t\t\t\tSelected\tConsolidated\tFinancial\tData.',
#  'Item\t7.\tManagement’s\tDiscussion\tand\tAnalysis\tof\tFinancial\tCondition\tand\tResults\tof\tOperations.',
#  'Item\t7A.\tQuantitative\tand\tQualitative\tDisclosures\tabout\tMarket\tRisks.',
#  'Item\t8.\tFinancial\tStatements\tand\tSupplementary\tData.',
#  'Item\t9.\tChanges\tin\tand\tDisagreements\twith\tAccountants\ton\tAccounting\tand\tFinancial\tDisclosure.',
#  'Item\t9A.\tControls\tand\tProcedures.',
#  'Item\t9B.\tOther\tInformation.',
#  'Item\t10.\tDirectors,\tExecutive\tOfficers\tand\tCorporate\tGovernance.',
#  'Item\t11.\tExecutive\tCompensation.',
#  'Item\t12.\tSecurity\tOwnership\tof\tCertain\tBeneficial\tOwners\tand\tManagement\tand\tRelated\tStockholder\tMatters.',
#  'Item\t13.\tCertain\tRelationships\tand\tRelated\tTransactions,\tand\tDirector\tIndependence.',
#  'Item\t14.\tPrincipal\tAccountant\tFees\tand\tServices.',
#  'Item\t15.\t\t\t\t\tExhibits,\tFinancial\tStatement\tSchedules.',
#  'Item\t16.\tForm\t10-K\tSummary.']

# %%
##### ITEM 1
matches = re.compile(r'^ITEM.*1.*BUSINESS', re.IGNORECASE)
#item7 = [matches.search(x) for x in result]
idx1 = rawList.index([x for x in rawList if matches.search(x) != None][-1])

##### ITEM 1A
matches = re.compile(r'^ITEM.*1(A| A)', re.IGNORECASE)
#item7 = [matches.search(x) for x in result]
idx1a = rawList.index([x for x in rawList if matches.search(x) != None][-1])

item1_company.append(' '.join(rawList[idx1:idx1a]).replace('\t', ' '))

# %%
idx1
# Out:
# 203
